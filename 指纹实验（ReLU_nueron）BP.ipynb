# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from glob import glob
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from torchvision import transforms
import os
from PIL import Image
import math

# 获取所有图像路径，递归查找
data = glob(r'D:\PycharmProjects\保存的参数\fingerprints\DB*\**\*.tif', recursive=True)
images = []

def readImages(data):
    for img_path in data:
        print(f"尝试读取图像: {img_path}")
        try:
            img = Image.open(img_path).convert("RGB").resize((224, 224))
            images.append(np.array(img))
        except Exception as e:
            print(f"无法读取图像: {img_path}，错误信息: {e}")
    return images

# 读取图像
images = readImages(data)

if len(images) == 0:
    raise ValueError("没有成功读取任何图像，请检查文件路径和格式。")

# 转换为 float32 类型并归一化
images_arr = np.asarray(images).astype('float32') / 255.0

if len(images_arr.shape) == 4:
    images_arr = np.transpose(images_arr, (0, 3, 1, 2))
else:
    raise ValueError("图像数组的形状不正确，检查读取步骤。")

# 划分训练集和验证集
train_X, valid_X, train_ground, valid_ground = train_test_split(
    images_arr, images_arr, test_size=0.2, random_state=13
)

# 转换为 PyTorch 张量
train_X = torch.tensor(train_X, dtype=torch.float32)
valid_X = torch.tensor(valid_X, dtype=torch.float32)
train_ground = torch.tensor(train_ground, dtype=torch.float32)
valid_ground = torch.tensor(valid_ground, dtype=torch.float32)

train_loader = DataLoader(TensorDataset(train_X, train_ground), batch_size=128, shuffle=True)
valid_loader = DataLoader(TensorDataset(valid_X, valid_ground), batch_size=128, shuffle=False)
# Out:
# 尝试读取图像: C:\fingerprints\DB1_B\101_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\101_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\102_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\103_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\104_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\105_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\106_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\107_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\108_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\109_8.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_1.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_2.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_3.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_4.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_5.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_6.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_7.tif
# 尝试读取图像: C:\fingerprints\DB1_B\110_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\101_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\102_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\103_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\104_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\105_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\106_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\107_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\108_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\109_8.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_1.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_2.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_3.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_4.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_5.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_6.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_7.tif
# 尝试读取图像: C:\fingerprints\DB2_B\110_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\101_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\102_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\103_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\104_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\105_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\106_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\107_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\108_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\109_8.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_1.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_2.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_3.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_4.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_5.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_6.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_7.tif
# 尝试读取图像: C:\fingerprints\DB3_B\110_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\101_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\102_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\103_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\104_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\105_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\106_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\107_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\108_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\109_8.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_1.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_2.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_3.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_4.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_5.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_6.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_7.tif
# 尝试读取图像: C:\fingerprints\DB4_B\110_8.tif

# %%
# 自定义 ReLU 激活函数
class CustomReLU(nn.Module):
    def __init__(self):
        super(CustomReLU, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(1.0))  # 初始化 sigma

    def forward(self, x):
        return torch.max(x, self.sigma * x)

# 定义自动编码器模型
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            CustomReLU(),  # 使用自定义的 ReLU
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            CustomReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            CustomReLU()
        )

        self.decoder = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            CustomReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
            CustomReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 3, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# 实例化模型
autoencoder = Autoencoder()
device = torch.device("cpu")
autoencoder.to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(autoencoder.parameters(), lr=0.001)

# 训练模型的函数
def train_model(model, train_loader, valid_loader, criterion, optimizer, epochs=300):
    model.train()
    train_loss = []
    valid_loss = []

    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_loss.append(running_loss / len(train_loader))

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in valid_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                val_loss += criterion(outputs, targets).item()

        valid_loss.append(val_loss / len(valid_loader))

        for name, layer in model.named_modules():
            if isinstance(layer, CustomReLU):
                print(f"Epoch {epoch+1}: {name} sigma = {layer.sigma.item():.4f}")

        print(f"Epoch {epoch+1}/{epochs}, Training Loss: {train_loss[-1]:.4f}, Validation Loss: {valid_loss[-1]:.4f}")

    return train_loss, valid_loss

# 训练模型
train_loss, valid_loss = train_model(autoencoder, train_loader, valid_loader, criterion, optimizer, epochs=300)
# Out:
# Epoch 1: encoder.1 sigma = 0.9995
# Epoch 1: encoder.4 sigma = 0.9996
# Epoch 1: encoder.7 sigma = 0.9995
# Epoch 1: decoder.1 sigma = 0.9996
# Epoch 1: decoder.4 sigma = 0.9996
# Epoch 1/300, Training Loss: 0.0606, Validation Loss: 0.0792
# Epoch 2: encoder.1 sigma = 0.9984
# Epoch 2: encoder.4 sigma = 0.9986
# Epoch 2: encoder.7 sigma = 0.9983
# Epoch 2: decoder.1 sigma = 0.9984
# Epoch 2: decoder.4 sigma = 0.9984
# Epoch 2/300, Training Loss: 0.0809, Validation Loss: 0.0663
# Epoch 3: encoder.1 sigma = 0.9979
# Epoch 3: encoder.4 sigma = 0.9983
# Epoch 3: encoder.7 sigma = 0.9974
# Epoch 3: decoder.1 sigma = 0.9977
# Epoch 3: decoder.4 sigma = 0.9977
# Epoch 3/300, Training Loss: 0.0520, Validation Loss: 0.0424
# Epoch 4: encoder.1 sigma = 0.9978
# Epoch 4: encoder.4 sigma = 0.9982
# Epoch 4: encoder.7 sigma = 0.9969
# Epoch 4: decoder.1 sigma = 0.9974
# Epoch 4: decoder.4 sigma = 0.9974
# Epoch 4/300, Training Loss: 0.0391, Validation Loss: 0.0364
# Epoch 5: encoder.1 sigma = 0.9974
# Epoch 5: encoder.4 sigma = 0.9979
# Epoch 5: encoder.7 sigma = 0.9964
# Epoch 5: decoder.1 sigma = 0.9970
# Epoch 5: decoder.4 sigma = 0.9970
# Epoch 5/300, Training Loss: 0.0332, Validation Loss: 0.0290
# Epoch 6: encoder.1 sigma = 0.9976
# Epoch 6: encoder.4 sigma = 0.9979
# Epoch 6: encoder.7 sigma = 0.9962
# Epoch 6: decoder.1 sigma = 0.9970
# Epoch 6: decoder.4 sigma = 0.9969
# Epoch 6/300, Training Loss: 0.0238, Validation Loss: 0.0208
# Epoch 7: encoder.1 sigma = 0.9976
# Epoch 7: encoder.4 sigma = 0.9978
# Epoch 7: encoder.7 sigma = 0.9960
# Epoch 7: decoder.1 sigma = 0.9969
# Epoch 7: decoder.4 sigma = 0.9968
# Epoch 7/300, Training Loss: 0.0216, Validation Loss: 0.0235
# Epoch 8: encoder.1 sigma = 0.9971
# Epoch 8: encoder.4 sigma = 0.9976
# Epoch 8: encoder.7 sigma = 0.9955
# Epoch 8: decoder.1 sigma = 0.9965
# Epoch 8: decoder.4 sigma = 0.9964
# Epoch 8/300, Training Loss: 0.0226, Validation Loss: 0.0204
# Epoch 9: encoder.1 sigma = 0.9966
# Epoch 9: encoder.4 sigma = 0.9973
# Epoch 9: encoder.7 sigma = 0.9949
# Epoch 9: decoder.1 sigma = 0.9960
# Epoch 9: decoder.4 sigma = 0.9958
# Epoch 9/300, Training Loss: 0.0187, Validation Loss: 0.0199
# Epoch 10: encoder.1 sigma = 0.9962
# Epoch 10: encoder.4 sigma = 0.9971
# Epoch 10: encoder.7 sigma = 0.9945
# Epoch 10: decoder.1 sigma = 0.9957
# Epoch 10: decoder.4 sigma = 0.9954
# Epoch 10/300, Training Loss: 0.0187, Validation Loss: 0.0197
# Epoch 11: encoder.1 sigma = 0.9961
# Epoch 11: encoder.4 sigma = 0.9970
# Epoch 11: encoder.7 sigma = 0.9942
# Epoch 11: decoder.1 sigma = 0.9955
# Epoch 11: decoder.4 sigma = 0.9952
# Epoch 11/300, Training Loss: 0.0178, Validation Loss: 0.0186
# Epoch 12: encoder.1 sigma = 0.9960
# Epoch 12: encoder.4 sigma = 0.9969
# Epoch 12: encoder.7 sigma = 0.9940
# Epoch 12: decoder.1 sigma = 0.9953
# Epoch 12: decoder.4 sigma = 0.9951
# Epoch 12/300, Training Loss: 0.0180, Validation Loss: 0.0192
# Epoch 13: encoder.1 sigma = 0.9956
# Epoch 13: encoder.4 sigma = 0.9968
# Epoch 13: encoder.7 sigma = 0.9936
# Epoch 13: decoder.1 sigma = 0.9950
# Epoch 13: decoder.4 sigma = 0.9947
# Epoch 13/300, Training Loss: 0.0180, Validation Loss: 0.0177
# Epoch 14: encoder.1 sigma = 0.9952
# Epoch 14: encoder.4 sigma = 0.9965
# Epoch 14: encoder.7 sigma = 0.9931
# Epoch 14: decoder.1 sigma = 0.9947
# Epoch 14: decoder.4 sigma = 0.9943
# Epoch 14/300, Training Loss: 0.0165, Validation Loss: 0.0175
# Epoch 15: encoder.1 sigma = 0.9950
# Epoch 15: encoder.4 sigma = 0.9964
# Epoch 15: encoder.7 sigma = 0.9928
# Epoch 15: decoder.1 sigma = 0.9945
# Epoch 15: decoder.4 sigma = 0.9940
# Epoch 15/300, Training Loss: 0.0167, Validation Loss: 0.0182
# Epoch 16: encoder.1 sigma = 0.9949
# Epoch 16: encoder.4 sigma = 0.9964
# Epoch 16: encoder.7 sigma = 0.9926
# Epoch 16: decoder.1 sigma = 0.9944
# Epoch 16: decoder.4 sigma = 0.9939
# Epoch 16/300, Training Loss: 0.0168, Validation Loss: 0.0172
# Epoch 17: encoder.1 sigma = 0.9949
# Epoch 17: encoder.4 sigma = 0.9965
# Epoch 17: encoder.7 sigma = 0.9925
# Epoch 17: decoder.1 sigma = 0.9944
# Epoch 17: decoder.4 sigma = 0.9938
# Epoch 17/300, Training Loss: 0.0160, Validation Loss: 0.0171
# Epoch 18: encoder.1 sigma = 0.9948
# Epoch 18: encoder.4 sigma = 0.9965
# Epoch 18: encoder.7 sigma = 0.9923
# Epoch 18: decoder.1 sigma = 0.9943
# Epoch 18: decoder.4 sigma = 0.9937
# Epoch 18/300, Training Loss: 0.0161, Validation Loss: 0.0172
# Epoch 19: encoder.1 sigma = 0.9947
# Epoch 19: encoder.4 sigma = 0.9965
# Epoch 19: encoder.7 sigma = 0.9921
# Epoch 19: decoder.1 sigma = 0.9942
# Epoch 19: decoder.4 sigma = 0.9935
# Epoch 19/300, Training Loss: 0.0162, Validation Loss: 0.0171
# Epoch 20: encoder.1 sigma = 0.9946
# Epoch 20: encoder.4 sigma = 0.9964
# Epoch 20: encoder.7 sigma = 0.9919
# Epoch 20: decoder.1 sigma = 0.9941
# Epoch 20: decoder.4 sigma = 0.9933
# Epoch 20/300, Training Loss: 0.0160, Validation Loss: 0.0169
# Epoch 21: encoder.1 sigma = 0.9946
# Epoch 21: encoder.4 sigma = 0.9965
# Epoch 21: encoder.7 sigma = 0.9917
# Epoch 21: decoder.1 sigma = 0.9941
# Epoch 21: decoder.4 sigma = 0.9932
# Epoch 21/300, Training Loss: 0.0158, Validation Loss: 0.0169
# Epoch 22: encoder.1 sigma = 0.9946
# Epoch 22: encoder.4 sigma = 0.9965
# Epoch 22: encoder.7 sigma = 0.9916
# Epoch 22: decoder.1 sigma = 0.9941
# Epoch 22: decoder.4 sigma = 0.9931
# Epoch 22/300, Training Loss: 0.0158, Validation Loss: 0.0169
# Epoch 23: encoder.1 sigma = 0.9947
# Epoch 23: encoder.4 sigma = 0.9966
# Epoch 23: encoder.7 sigma = 0.9915
# Epoch 23: decoder.1 sigma = 0.9941
# Epoch 23: decoder.4 sigma = 0.9931
# Epoch 23/300, Training Loss: 0.0159, Validation Loss: 0.0168
# Epoch 24: encoder.1 sigma = 0.9948
# Epoch 24: encoder.4 sigma = 0.9967
# Epoch 24: encoder.7 sigma = 0.9915
# Epoch 24: decoder.1 sigma = 0.9942
# Epoch 24: decoder.4 sigma = 0.9931
# Epoch 24/300, Training Loss: 0.0158, Validation Loss: 0.0167
# Epoch 25: encoder.1 sigma = 0.9949
# Epoch 25: encoder.4 sigma = 0.9968
# Epoch 25: encoder.7 sigma = 0.9914
# Epoch 25: decoder.1 sigma = 0.9942
# Epoch 25: decoder.4 sigma = 0.9930
# Epoch 25/300, Training Loss: 0.0156, Validation Loss: 0.0166
# Epoch 26: encoder.1 sigma = 0.9950
# Epoch 26: encoder.4 sigma = 0.9969
# Epoch 26: encoder.7 sigma = 0.9913
# Epoch 26: decoder.1 sigma = 0.9942
# Epoch 26: decoder.4 sigma = 0.9930
# Epoch 26/300, Training Loss: 0.0156, Validation Loss: 0.0166
# Epoch 27: encoder.1 sigma = 0.9951
# Epoch 27: encoder.4 sigma = 0.9970
# Epoch 27: encoder.7 sigma = 0.9913
# Epoch 27: decoder.1 sigma = 0.9943
# Epoch 27: decoder.4 sigma = 0.9930
# Epoch 27/300, Training Loss: 0.0156, Validation Loss: 0.0165
# Epoch 28: encoder.1 sigma = 0.9952
# Epoch 28: encoder.4 sigma = 0.9971
# Epoch 28: encoder.7 sigma = 0.9912
# Epoch 28: decoder.1 sigma = 0.9943
# Epoch 28: decoder.4 sigma = 0.9930
# Epoch 28/300, Training Loss: 0.0155, Validation Loss: 0.0165
# Epoch 29: encoder.1 sigma = 0.9953
# Epoch 29: encoder.4 sigma = 0.9973
# Epoch 29: encoder.7 sigma = 0.9911
# Epoch 29: decoder.1 sigma = 0.9944
# Epoch 29: decoder.4 sigma = 0.9930
# Epoch 29/300, Training Loss: 0.0154, Validation Loss: 0.0164
# Epoch 30: encoder.1 sigma = 0.9954
# Epoch 30: encoder.4 sigma = 0.9974
# Epoch 30: encoder.7 sigma = 0.9911
# Epoch 30: decoder.1 sigma = 0.9945
# Epoch 30: decoder.4 sigma = 0.9929
# Epoch 30/300, Training Loss: 0.0154, Validation Loss: 0.0164
# Epoch 31: encoder.1 sigma = 0.9955
# Epoch 31: encoder.4 sigma = 0.9975
# Epoch 31: encoder.7 sigma = 0.9910
# Epoch 31: decoder.1 sigma = 0.9946
# Epoch 31: decoder.4 sigma = 0.9929
# Epoch 31/300, Training Loss: 0.0154, Validation Loss: 0.0164
# Epoch 32: encoder.1 sigma = 0.9957
# Epoch 32: encoder.4 sigma = 0.9976
# Epoch 32: encoder.7 sigma = 0.9910
# Epoch 32: decoder.1 sigma = 0.9946
# Epoch 32: decoder.4 sigma = 0.9929
# Epoch 32/300, Training Loss: 0.0157, Validation Loss: 0.0178
# Epoch 33: encoder.1 sigma = 0.9958
# Epoch 33: encoder.4 sigma = 0.9977
# Epoch 33: encoder.7 sigma = 0.9909
# Epoch 33: decoder.1 sigma = 0.9947
# Epoch 33: decoder.4 sigma = 0.9929
# Epoch 33/300, Training Loss: 0.0176, Validation Loss: 0.0174
# Epoch 34: encoder.1 sigma = 0.9958
# Epoch 34: encoder.4 sigma = 0.9978
# Epoch 34: encoder.7 sigma = 0.9909
# Epoch 34: decoder.1 sigma = 0.9947
# Epoch 34: decoder.4 sigma = 0.9928
# Epoch 34/300, Training Loss: 0.0158, Validation Loss: 0.0168
# Epoch 35: encoder.1 sigma = 0.9960
# Epoch 35: encoder.4 sigma = 0.9979
# Epoch 35: encoder.7 sigma = 0.9908
# Epoch 35: decoder.1 sigma = 0.9947
# Epoch 35: decoder.4 sigma = 0.9928
# Epoch 35/300, Training Loss: 0.0155, Validation Loss: 0.0165
# Epoch 36: encoder.1 sigma = 0.9961
# Epoch 36: encoder.4 sigma = 0.9980
# Epoch 36: encoder.7 sigma = 0.9907
# Epoch 36: decoder.1 sigma = 0.9948
# Epoch 36: decoder.4 sigma = 0.9928
# Epoch 36/300, Training Loss: 0.0156, Validation Loss: 0.0162
# Epoch 37: encoder.1 sigma = 0.9962
# Epoch 37: encoder.4 sigma = 0.9982
# Epoch 37: encoder.7 sigma = 0.9907
# Epoch 37: decoder.1 sigma = 0.9949
# Epoch 37: decoder.4 sigma = 0.9927
# Epoch 37/300, Training Loss: 0.0154, Validation Loss: 0.0161
# Epoch 38: encoder.1 sigma = 0.9964
# Epoch 38: encoder.4 sigma = 0.9983
# Epoch 38: encoder.7 sigma = 0.9906
# Epoch 38: decoder.1 sigma = 0.9949
# Epoch 38: decoder.4 sigma = 0.9927
# Epoch 38/300, Training Loss: 0.0153, Validation Loss: 0.0162
# Epoch 39: encoder.1 sigma = 0.9965
# Epoch 39: encoder.4 sigma = 0.9984
# Epoch 39: encoder.7 sigma = 0.9906
# Epoch 39: decoder.1 sigma = 0.9950
# Epoch 39: decoder.4 sigma = 0.9927
# Epoch 39/300, Training Loss: 0.0153, Validation Loss: 0.0161
# Epoch 40: encoder.1 sigma = 0.9967
# Epoch 40: encoder.4 sigma = 0.9985
# Epoch 40: encoder.7 sigma = 0.9905
# Epoch 40: decoder.1 sigma = 0.9951
# Epoch 40: decoder.4 sigma = 0.9927
# Epoch 40/300, Training Loss: 0.0152, Validation Loss: 0.0162
# Epoch 41: encoder.1 sigma = 0.9968
# Epoch 41: encoder.4 sigma = 0.9987
# Epoch 41: encoder.7 sigma = 0.9905
# Epoch 41: decoder.1 sigma = 0.9952
# Epoch 41: decoder.4 sigma = 0.9928
# Epoch 41/300, Training Loss: 0.0152, Validation Loss: 0.0161
# Epoch 42: encoder.1 sigma = 0.9970
# Epoch 42: encoder.4 sigma = 0.9989
# Epoch 42: encoder.7 sigma = 0.9904
# Epoch 42: decoder.1 sigma = 0.9953
# Epoch 42: decoder.4 sigma = 0.9928
# Epoch 42/300, Training Loss: 0.0151, Validation Loss: 0.0161
# Epoch 43: encoder.1 sigma = 0.9972
# Epoch 43: encoder.4 sigma = 0.9990
# Epoch 43: encoder.7 sigma = 0.9904
# Epoch 43: decoder.1 sigma = 0.9954
# Epoch 43: decoder.4 sigma = 0.9928
# Epoch 43/300, Training Loss: 0.0150, Validation Loss: 0.0161
# Epoch 44: encoder.1 sigma = 0.9974
# Epoch 44: encoder.4 sigma = 0.9992
# Epoch 44: encoder.7 sigma = 0.9904
# Epoch 44: decoder.1 sigma = 0.9955
# Epoch 44: decoder.4 sigma = 0.9929
# Epoch 44/300, Training Loss: 0.0150, Validation Loss: 0.0160
# Epoch 45: encoder.1 sigma = 0.9975
# Epoch 45: encoder.4 sigma = 0.9994
# Epoch 45: encoder.7 sigma = 0.9904
# Epoch 45: decoder.1 sigma = 0.9956
# Epoch 45: decoder.4 sigma = 0.9929
# Epoch 45/300, Training Loss: 0.0149, Validation Loss: 0.0160
# Epoch 46: encoder.1 sigma = 0.9977
# Epoch 46: encoder.4 sigma = 0.9996
# Epoch 46: encoder.7 sigma = 0.9903
# Epoch 46: decoder.1 sigma = 0.9957
# Epoch 46: decoder.4 sigma = 0.9929
# Epoch 46/300, Training Loss: 0.0149, Validation Loss: 0.0160
# Epoch 47: encoder.1 sigma = 0.9979
# Epoch 47: encoder.4 sigma = 0.9998
# Epoch 47: encoder.7 sigma = 0.9903
# Epoch 47: decoder.1 sigma = 0.9958
# Epoch 47: decoder.4 sigma = 0.9930
# Epoch 47/300, Training Loss: 0.0149, Validation Loss: 0.0160
# Epoch 48: encoder.1 sigma = 0.9981
# Epoch 48: encoder.4 sigma = 1.0000
# Epoch 48: encoder.7 sigma = 0.9903
# Epoch 48: decoder.1 sigma = 0.9960
# Epoch 48: decoder.4 sigma = 0.9931
# Epoch 48/300, Training Loss: 0.0149, Validation Loss: 0.0159
# Epoch 49: encoder.1 sigma = 0.9983
# Epoch 49: encoder.4 sigma = 1.0001
# Epoch 49: encoder.7 sigma = 0.9903
# Epoch 49: decoder.1 sigma = 0.9961
# Epoch 49: decoder.4 sigma = 0.9932
# Epoch 49/300, Training Loss: 0.0150, Validation Loss: 0.0156
# Epoch 50: encoder.1 sigma = 0.9985
# Epoch 50: encoder.4 sigma = 1.0002
# Epoch 50: encoder.7 sigma = 0.9903
# Epoch 50: decoder.1 sigma = 0.9962
# Epoch 50: decoder.4 sigma = 0.9932
# Epoch 50/300, Training Loss: 0.0147, Validation Loss: 0.0156
# Epoch 51: encoder.1 sigma = 0.9987
# Epoch 51: encoder.4 sigma = 1.0003
# Epoch 51: encoder.7 sigma = 0.9903
# Epoch 51: decoder.1 sigma = 0.9963
# Epoch 51: decoder.4 sigma = 0.9933
# Epoch 51/300, Training Loss: 0.0146, Validation Loss: 0.0156
# Epoch 52: encoder.1 sigma = 0.9989
# Epoch 52: encoder.4 sigma = 1.0004
# Epoch 52: encoder.7 sigma = 0.9903
# Epoch 52: decoder.1 sigma = 0.9965
# Epoch 52: decoder.4 sigma = 0.9934
# Epoch 52/300, Training Loss: 0.0146, Validation Loss: 0.0155
# Epoch 53: encoder.1 sigma = 0.9991
# Epoch 53: encoder.4 sigma = 1.0004
# Epoch 53: encoder.7 sigma = 0.9903
# Epoch 53: decoder.1 sigma = 0.9966
# Epoch 53: decoder.4 sigma = 0.9935
# Epoch 53/300, Training Loss: 0.0145, Validation Loss: 0.0154
# Epoch 54: encoder.1 sigma = 0.9994
# Epoch 54: encoder.4 sigma = 1.0004
# Epoch 54: encoder.7 sigma = 0.9903
# Epoch 54: decoder.1 sigma = 0.9968
# Epoch 54: decoder.4 sigma = 0.9936
# Epoch 54/300, Training Loss: 0.0145, Validation Loss: 0.0154
# Epoch 55: encoder.1 sigma = 0.9996
# Epoch 55: encoder.4 sigma = 1.0004
# Epoch 55: encoder.7 sigma = 0.9902
# Epoch 55: decoder.1 sigma = 0.9969
# Epoch 55: decoder.4 sigma = 0.9937
# Epoch 55/300, Training Loss: 0.0144, Validation Loss: 0.0153
# Epoch 56: encoder.1 sigma = 0.9998
# Epoch 56: encoder.4 sigma = 1.0004
# Epoch 56: encoder.7 sigma = 0.9902
# Epoch 56: decoder.1 sigma = 0.9971
# Epoch 56: decoder.4 sigma = 0.9938
# Epoch 56/300, Training Loss: 0.0144, Validation Loss: 0.0153
# Epoch 57: encoder.1 sigma = 1.0001
# Epoch 57: encoder.4 sigma = 1.0004
# Epoch 57: encoder.7 sigma = 0.9903
# Epoch 57: decoder.1 sigma = 0.9973
# Epoch 57: decoder.4 sigma = 0.9939
# Epoch 57/300, Training Loss: 0.0144, Validation Loss: 0.0153
# Epoch 58: encoder.1 sigma = 1.0005
# Epoch 58: encoder.4 sigma = 1.0003
# Epoch 58: encoder.7 sigma = 0.9903
# Epoch 58: decoder.1 sigma = 0.9974
# Epoch 58: decoder.4 sigma = 0.9940
# Epoch 58/300, Training Loss: 0.0143, Validation Loss: 0.0152
# Epoch 59: encoder.1 sigma = 1.0008
# Epoch 59: encoder.4 sigma = 1.0003
# Epoch 59: encoder.7 sigma = 0.9902
# Epoch 59: decoder.1 sigma = 0.9976
# Epoch 59: decoder.4 sigma = 0.9941
# Epoch 59/300, Training Loss: 0.0142, Validation Loss: 0.0151
# Epoch 60: encoder.1 sigma = 1.0010
# Epoch 60: encoder.4 sigma = 1.0002
# Epoch 60: encoder.7 sigma = 0.9902
# Epoch 60: decoder.1 sigma = 0.9977
# Epoch 60: decoder.4 sigma = 0.9942
# Epoch 60/300, Training Loss: 0.0142, Validation Loss: 0.0156
# Epoch 61: encoder.1 sigma = 1.0012
# Epoch 61: encoder.4 sigma = 1.0001
# Epoch 61: encoder.7 sigma = 0.9902
# Epoch 61: decoder.1 sigma = 0.9979
# Epoch 61: decoder.4 sigma = 0.9943
# Epoch 61/300, Training Loss: 0.0147, Validation Loss: 0.0152
# Epoch 62: encoder.1 sigma = 1.0014
# Epoch 62: encoder.4 sigma = 1.0001
# Epoch 62: encoder.7 sigma = 0.9902
# Epoch 62: decoder.1 sigma = 0.9981
# Epoch 62: decoder.4 sigma = 0.9944
# Epoch 62/300, Training Loss: 0.0141, Validation Loss: 0.0150
# Epoch 63: encoder.1 sigma = 1.0016
# Epoch 63: encoder.4 sigma = 1.0000
# Epoch 63: encoder.7 sigma = 0.9902
# Epoch 63: decoder.1 sigma = 0.9982
# Epoch 63: decoder.4 sigma = 0.9945
# Epoch 63/300, Training Loss: 0.0141, Validation Loss: 0.0149
# Epoch 64: encoder.1 sigma = 1.0017
# Epoch 64: encoder.4 sigma = 0.9999
# Epoch 64: encoder.7 sigma = 0.9902
# Epoch 64: decoder.1 sigma = 0.9984
# Epoch 64: decoder.4 sigma = 0.9946
# Epoch 64/300, Training Loss: 0.0139, Validation Loss: 0.0149
# Epoch 65: encoder.1 sigma = 1.0019
# Epoch 65: encoder.4 sigma = 1.0000
# Epoch 65: encoder.7 sigma = 0.9902
# Epoch 65: decoder.1 sigma = 0.9985
# Epoch 65: decoder.4 sigma = 0.9947
# Epoch 65/300, Training Loss: 0.0139, Validation Loss: 0.0149
# Epoch 66: encoder.1 sigma = 1.0020
# Epoch 66: encoder.4 sigma = 1.0001
# Epoch 66: encoder.7 sigma = 0.9902
# Epoch 66: decoder.1 sigma = 0.9987
# Epoch 66: decoder.4 sigma = 0.9948
# Epoch 66/300, Training Loss: 0.0141, Validation Loss: 0.0148
# Epoch 67: encoder.1 sigma = 1.0020
# Epoch 67: encoder.4 sigma = 1.0001
# Epoch 67: encoder.7 sigma = 0.9902
# Epoch 67: decoder.1 sigma = 0.9989
# Epoch 67: decoder.4 sigma = 0.9949
# Epoch 67/300, Training Loss: 0.0138, Validation Loss: 0.0150
# Epoch 68: encoder.1 sigma = 1.0022
# Epoch 68: encoder.4 sigma = 1.0001
# Epoch 68: encoder.7 sigma = 0.9902
# Epoch 68: decoder.1 sigma = 0.9990
# Epoch 68: decoder.4 sigma = 0.9950
# Epoch 68/300, Training Loss: 0.0141, Validation Loss: 0.0147
# Epoch 69: encoder.1 sigma = 1.0024
# Epoch 69: encoder.4 sigma = 1.0002
# Epoch 69: encoder.7 sigma = 0.9902
# Epoch 69: decoder.1 sigma = 0.9992
# Epoch 69: decoder.4 sigma = 0.9952
# Epoch 69/300, Training Loss: 0.0137, Validation Loss: 0.0148
# Epoch 70: encoder.1 sigma = 1.0024
# Epoch 70: encoder.4 sigma = 1.0001
# Epoch 70: encoder.7 sigma = 0.9902
# Epoch 70: decoder.1 sigma = 0.9994
# Epoch 70: decoder.4 sigma = 0.9953
# Epoch 70/300, Training Loss: 0.0138, Validation Loss: 0.0144
# Epoch 71: encoder.1 sigma = 1.0025
# Epoch 71: encoder.4 sigma = 1.0001
# Epoch 71: encoder.7 sigma = 0.9901
# Epoch 71: decoder.1 sigma = 0.9996
# Epoch 71: decoder.4 sigma = 0.9954
# Epoch 71/300, Training Loss: 0.0136, Validation Loss: 0.0145
# Epoch 72: encoder.1 sigma = 1.0028
# Epoch 72: encoder.4 sigma = 1.0001
# Epoch 72: encoder.7 sigma = 0.9902
# Epoch 72: decoder.1 sigma = 0.9998
# Epoch 72: decoder.4 sigma = 0.9956
# Epoch 72/300, Training Loss: 0.0134, Validation Loss: 0.0145
# Epoch 73: encoder.1 sigma = 1.0028
# Epoch 73: encoder.4 sigma = 1.0001
# Epoch 73: encoder.7 sigma = 0.9902
# Epoch 73: decoder.1 sigma = 0.9999
# Epoch 73: decoder.4 sigma = 0.9957
# Epoch 73/300, Training Loss: 0.0134, Validation Loss: 0.0143
# Epoch 74: encoder.1 sigma = 1.0030
# Epoch 74: encoder.4 sigma = 1.0001
# Epoch 74: encoder.7 sigma = 0.9902
# Epoch 74: decoder.1 sigma = 1.0002
# Epoch 74: decoder.4 sigma = 0.9959
# Epoch 74/300, Training Loss: 0.0134, Validation Loss: 0.0141
# Epoch 75: encoder.1 sigma = 1.0032
# Epoch 75: encoder.4 sigma = 1.0000
# Epoch 75: encoder.7 sigma = 0.9902
# Epoch 75: decoder.1 sigma = 1.0004
# Epoch 75: decoder.4 sigma = 0.9961
# Epoch 75/300, Training Loss: 0.0131, Validation Loss: 0.0140
# Epoch 76: encoder.1 sigma = 1.0034
# Epoch 76: encoder.4 sigma = 1.0000
# Epoch 76: encoder.7 sigma = 0.9902
# Epoch 76: decoder.1 sigma = 1.0006
# Epoch 76: decoder.4 sigma = 0.9963
# Epoch 76/300, Training Loss: 0.0130, Validation Loss: 0.0139
# Epoch 77: encoder.1 sigma = 1.0036
# Epoch 77: encoder.4 sigma = 1.0000
# Epoch 77: encoder.7 sigma = 0.9902
# Epoch 77: decoder.1 sigma = 1.0008
# Epoch 77: decoder.4 sigma = 0.9965
# Epoch 77/300, Training Loss: 0.0129, Validation Loss: 0.0138
# Epoch 78: encoder.1 sigma = 1.0038
# Epoch 78: encoder.4 sigma = 1.0000
# Epoch 78: encoder.7 sigma = 0.9903
# Epoch 78: decoder.1 sigma = 1.0009
# Epoch 78: decoder.4 sigma = 0.9967
# Epoch 78/300, Training Loss: 0.0128, Validation Loss: 0.0137
# Epoch 79: encoder.1 sigma = 1.0041
# Epoch 79: encoder.4 sigma = 1.0000
# Epoch 79: encoder.7 sigma = 0.9903
# Epoch 79: decoder.1 sigma = 1.0011
# Epoch 79: decoder.4 sigma = 0.9969
# Epoch 79/300, Training Loss: 0.0127, Validation Loss: 0.0136
# Epoch 80: encoder.1 sigma = 1.0043
# Epoch 80: encoder.4 sigma = 1.0000
# Epoch 80: encoder.7 sigma = 0.9903
# Epoch 80: decoder.1 sigma = 1.0012
# Epoch 80: decoder.4 sigma = 0.9971
# Epoch 80/300, Training Loss: 0.0126, Validation Loss: 0.0135
# Epoch 81: encoder.1 sigma = 1.0046
# Epoch 81: encoder.4 sigma = 1.0001
# Epoch 81: encoder.7 sigma = 0.9904
# Epoch 81: decoder.1 sigma = 1.0014
# Epoch 81: decoder.4 sigma = 0.9974
# Epoch 81/300, Training Loss: 0.0125, Validation Loss: 0.0135
# Epoch 82: encoder.1 sigma = 1.0047
# Epoch 82: encoder.4 sigma = 1.0000
# Epoch 82: encoder.7 sigma = 0.9904
# Epoch 82: decoder.1 sigma = 1.0015
# Epoch 82: decoder.4 sigma = 0.9976
# Epoch 82/300, Training Loss: 0.0124, Validation Loss: 0.0136
# Epoch 83: encoder.1 sigma = 1.0050
# Epoch 83: encoder.4 sigma = 1.0000
# Epoch 83: encoder.7 sigma = 0.9904
# Epoch 83: decoder.1 sigma = 1.0017
# Epoch 83: decoder.4 sigma = 0.9978
# Epoch 83/300, Training Loss: 0.0126, Validation Loss: 0.0132
# Epoch 84: encoder.1 sigma = 1.0054
# Epoch 84: encoder.4 sigma = 1.0001
# Epoch 84: encoder.7 sigma = 0.9904
# Epoch 84: decoder.1 sigma = 1.0018
# Epoch 84: decoder.4 sigma = 0.9981
# Epoch 84/300, Training Loss: 0.0123, Validation Loss: 0.0136
# Epoch 85: encoder.1 sigma = 1.0054
# Epoch 85: encoder.4 sigma = 1.0000
# Epoch 85: encoder.7 sigma = 0.9903
# Epoch 85: decoder.1 sigma = 1.0019
# Epoch 85: decoder.4 sigma = 0.9982
# Epoch 85/300, Training Loss: 0.0124, Validation Loss: 0.0134
# Epoch 86: encoder.1 sigma = 1.0056
# Epoch 86: encoder.4 sigma = 1.0000
# Epoch 86: encoder.7 sigma = 0.9903
# Epoch 86: decoder.1 sigma = 1.0020
# Epoch 86: decoder.4 sigma = 0.9985
# Epoch 86/300, Training Loss: 0.0124, Validation Loss: 0.0128
# Epoch 87: encoder.1 sigma = 1.0059
# Epoch 87: encoder.4 sigma = 1.0000
# Epoch 87: encoder.7 sigma = 0.9903
# Epoch 87: decoder.1 sigma = 1.0021
# Epoch 87: decoder.4 sigma = 0.9987
# Epoch 87/300, Training Loss: 0.0119, Validation Loss: 0.0128
# Epoch 88: encoder.1 sigma = 1.0060
# Epoch 88: encoder.4 sigma = 1.0001
# Epoch 88: encoder.7 sigma = 0.9903
# Epoch 88: decoder.1 sigma = 1.0022
# Epoch 88: decoder.4 sigma = 0.9989
# Epoch 88/300, Training Loss: 0.0118, Validation Loss: 0.0126
# Epoch 89: encoder.1 sigma = 1.0063
# Epoch 89: encoder.4 sigma = 1.0002
# Epoch 89: encoder.7 sigma = 0.9902
# Epoch 89: decoder.1 sigma = 1.0023
# Epoch 89: decoder.4 sigma = 0.9991
# Epoch 89/300, Training Loss: 0.0116, Validation Loss: 0.0124
# Epoch 90: encoder.1 sigma = 1.0065
# Epoch 90: encoder.4 sigma = 1.0002
# Epoch 90: encoder.7 sigma = 0.9902
# Epoch 90: decoder.1 sigma = 1.0024
# Epoch 90: decoder.4 sigma = 0.9994
# Epoch 90/300, Training Loss: 0.0114, Validation Loss: 0.0123
# Epoch 91: encoder.1 sigma = 1.0067
# Epoch 91: encoder.4 sigma = 1.0003
# Epoch 91: encoder.7 sigma = 0.9902
# Epoch 91: decoder.1 sigma = 1.0025
# Epoch 91: decoder.4 sigma = 0.9996
# Epoch 91/300, Training Loss: 0.0113, Validation Loss: 0.0121
# Epoch 92: encoder.1 sigma = 1.0070
# Epoch 92: encoder.4 sigma = 1.0003
# Epoch 92: encoder.7 sigma = 0.9902
# Epoch 92: decoder.1 sigma = 1.0027
# Epoch 92: decoder.4 sigma = 0.9999
# Epoch 92/300, Training Loss: 0.0111, Validation Loss: 0.0120
# Epoch 93: encoder.1 sigma = 1.0072
# Epoch 93: encoder.4 sigma = 1.0004
# Epoch 93: encoder.7 sigma = 0.9902
# Epoch 93: decoder.1 sigma = 1.0028
# Epoch 93: decoder.4 sigma = 1.0001
# Epoch 93/300, Training Loss: 0.0110, Validation Loss: 0.0119
# Epoch 94: encoder.1 sigma = 1.0075
# Epoch 94: encoder.4 sigma = 1.0004
# Epoch 94: encoder.7 sigma = 0.9901
# Epoch 94: decoder.1 sigma = 1.0029
# Epoch 94: decoder.4 sigma = 1.0004
# Epoch 94/300, Training Loss: 0.0109, Validation Loss: 0.0119
# Epoch 95: encoder.1 sigma = 1.0078
# Epoch 95: encoder.4 sigma = 1.0004
# Epoch 95: encoder.7 sigma = 0.9901
# Epoch 95: decoder.1 sigma = 1.0030
# Epoch 95: decoder.4 sigma = 1.0006
# Epoch 95/300, Training Loss: 0.0108, Validation Loss: 0.0116
# Epoch 96: encoder.1 sigma = 1.0080
# Epoch 96: encoder.4 sigma = 1.0004
# Epoch 96: encoder.7 sigma = 0.9901
# Epoch 96: decoder.1 sigma = 1.0032
# Epoch 96: decoder.4 sigma = 1.0008
# Epoch 96/300, Training Loss: 0.0106, Validation Loss: 0.0115
# Epoch 97: encoder.1 sigma = 1.0084
# Epoch 97: encoder.4 sigma = 1.0005
# Epoch 97: encoder.7 sigma = 0.9900
# Epoch 97: decoder.1 sigma = 1.0033
# Epoch 97: decoder.4 sigma = 1.0010
# Epoch 97/300, Training Loss: 0.0104, Validation Loss: 0.0113
# Epoch 98: encoder.1 sigma = 1.0086
# Epoch 98: encoder.4 sigma = 1.0005
# Epoch 98: encoder.7 sigma = 0.9900
# Epoch 98: decoder.1 sigma = 1.0034
# Epoch 98: decoder.4 sigma = 1.0012
# Epoch 98/300, Training Loss: 0.0103, Validation Loss: 0.0112
# Epoch 99: encoder.1 sigma = 1.0088
# Epoch 99: encoder.4 sigma = 1.0005
# Epoch 99: encoder.7 sigma = 0.9899
# Epoch 99: decoder.1 sigma = 1.0035
# Epoch 99: decoder.4 sigma = 1.0014
# Epoch 99/300, Training Loss: 0.0104, Validation Loss: 0.0114
# Epoch 100: encoder.1 sigma = 1.0091
# Epoch 100: encoder.4 sigma = 1.0005
# Epoch 100: encoder.7 sigma = 0.9898
# Epoch 100: decoder.1 sigma = 1.0036
# Epoch 100: decoder.4 sigma = 1.0016
# Epoch 100/300, Training Loss: 0.0102, Validation Loss: 0.0111
# Epoch 101: encoder.1 sigma = 1.0092
# Epoch 101: encoder.4 sigma = 1.0005
# Epoch 101: encoder.7 sigma = 0.9897
# Epoch 101: decoder.1 sigma = 1.0037
# Epoch 101: decoder.4 sigma = 1.0017
# Epoch 101/300, Training Loss: 0.0101, Validation Loss: 0.0110
# Epoch 102: encoder.1 sigma = 1.0095
# Epoch 102: encoder.4 sigma = 1.0005
# Epoch 102: encoder.7 sigma = 0.9896
# Epoch 102: decoder.1 sigma = 1.0038
# Epoch 102: decoder.4 sigma = 1.0018
# Epoch 102/300, Training Loss: 0.0100, Validation Loss: 0.0107
# Epoch 103: encoder.1 sigma = 1.0096
# Epoch 103: encoder.4 sigma = 1.0004
# Epoch 103: encoder.7 sigma = 0.9895
# Epoch 103: decoder.1 sigma = 1.0038
# Epoch 103: decoder.4 sigma = 1.0019
# Epoch 103/300, Training Loss: 0.0097, Validation Loss: 0.0106
# Epoch 104: encoder.1 sigma = 1.0098
# Epoch 104: encoder.4 sigma = 1.0004
# Epoch 104: encoder.7 sigma = 0.9893
# Epoch 104: decoder.1 sigma = 1.0039
# Epoch 104: decoder.4 sigma = 1.0021
# Epoch 104/300, Training Loss: 0.0097, Validation Loss: 0.0106
# Epoch 105: encoder.1 sigma = 1.0100
# Epoch 105: encoder.4 sigma = 1.0004
# Epoch 105: encoder.7 sigma = 0.9892
# Epoch 105: decoder.1 sigma = 1.0040
# Epoch 105: decoder.4 sigma = 1.0022
# Epoch 105/300, Training Loss: 0.0096, Validation Loss: 0.0104
# Epoch 106: encoder.1 sigma = 1.0102
# Epoch 106: encoder.4 sigma = 1.0003
# Epoch 106: encoder.7 sigma = 0.9890
# Epoch 106: decoder.1 sigma = 1.0041
# Epoch 106: decoder.4 sigma = 1.0023
# Epoch 106/300, Training Loss: 0.0094, Validation Loss: 0.0103
# Epoch 107: encoder.1 sigma = 1.0103
# Epoch 107: encoder.4 sigma = 1.0003
# Epoch 107: encoder.7 sigma = 0.9889
# Epoch 107: decoder.1 sigma = 1.0041
# Epoch 107: decoder.4 sigma = 1.0023
# Epoch 107/300, Training Loss: 0.0093, Validation Loss: 0.0103
# Epoch 108: encoder.1 sigma = 1.0105
# Epoch 108: encoder.4 sigma = 1.0002
# Epoch 108: encoder.7 sigma = 0.9887
# Epoch 108: decoder.1 sigma = 1.0042
# Epoch 108: decoder.4 sigma = 1.0024
# Epoch 108/300, Training Loss: 0.0093, Validation Loss: 0.0101
# Epoch 109: encoder.1 sigma = 1.0106
# Epoch 109: encoder.4 sigma = 1.0001
# Epoch 109: encoder.7 sigma = 0.9885
# Epoch 109: decoder.1 sigma = 1.0042
# Epoch 109: decoder.4 sigma = 1.0025
# Epoch 109/300, Training Loss: 0.0092, Validation Loss: 0.0100
# Epoch 110: encoder.1 sigma = 1.0108
# Epoch 110: encoder.4 sigma = 1.0001
# Epoch 110: encoder.7 sigma = 0.9883
# Epoch 110: decoder.1 sigma = 1.0043
# Epoch 110: decoder.4 sigma = 1.0026
# Epoch 110/300, Training Loss: 0.0091, Validation Loss: 0.0099
# Epoch 111: encoder.1 sigma = 1.0109
# Epoch 111: encoder.4 sigma = 1.0000
# Epoch 111: encoder.7 sigma = 0.9881
# Epoch 111: decoder.1 sigma = 1.0044
# Epoch 111: decoder.4 sigma = 1.0027
# Epoch 111/300, Training Loss: 0.0090, Validation Loss: 0.0100
# Epoch 112: encoder.1 sigma = 1.0111
# Epoch 112: encoder.4 sigma = 1.0000
# Epoch 112: encoder.7 sigma = 0.9879
# Epoch 112: decoder.1 sigma = 1.0045
# Epoch 112: decoder.4 sigma = 1.0028
# Epoch 112/300, Training Loss: 0.0089, Validation Loss: 0.0097
# Epoch 113: encoder.1 sigma = 1.0112
# Epoch 113: encoder.4 sigma = 1.0000
# Epoch 113: encoder.7 sigma = 0.9877
# Epoch 113: decoder.1 sigma = 1.0045
# Epoch 113: decoder.4 sigma = 1.0028
# Epoch 113/300, Training Loss: 0.0090, Validation Loss: 0.0098
# Epoch 114: encoder.1 sigma = 1.0112
# Epoch 114: encoder.4 sigma = 1.0000
# Epoch 114: encoder.7 sigma = 0.9875
# Epoch 114: decoder.1 sigma = 1.0046
# Epoch 114: decoder.4 sigma = 1.0029
# Epoch 114/300, Training Loss: 0.0088, Validation Loss: 0.0098
# Epoch 115: encoder.1 sigma = 1.0114
# Epoch 115: encoder.4 sigma = 1.0000
# Epoch 115: encoder.7 sigma = 0.9872
# Epoch 115: decoder.1 sigma = 1.0046
# Epoch 115: decoder.4 sigma = 1.0030
# Epoch 115/300, Training Loss: 0.0088, Validation Loss: 0.0095
# Epoch 116: encoder.1 sigma = 1.0116
# Epoch 116: encoder.4 sigma = 1.0001
# Epoch 116: encoder.7 sigma = 0.9870
# Epoch 116: decoder.1 sigma = 1.0047
# Epoch 116: decoder.4 sigma = 1.0030
# Epoch 116/300, Training Loss: 0.0086, Validation Loss: 0.0096
# Epoch 117: encoder.1 sigma = 1.0116
# Epoch 117: encoder.4 sigma = 1.0000
# Epoch 117: encoder.7 sigma = 0.9867
# Epoch 117: decoder.1 sigma = 1.0048
# Epoch 117: decoder.4 sigma = 1.0031
# Epoch 117/300, Training Loss: 0.0086, Validation Loss: 0.0097
# Epoch 118: encoder.1 sigma = 1.0117
# Epoch 118: encoder.4 sigma = 1.0001
# Epoch 118: encoder.7 sigma = 0.9865
# Epoch 118: decoder.1 sigma = 1.0049
# Epoch 118: decoder.4 sigma = 1.0032
# Epoch 118/300, Training Loss: 0.0086, Validation Loss: 0.0092
# Epoch 119: encoder.1 sigma = 1.0119
# Epoch 119: encoder.4 sigma = 1.0001
# Epoch 119: encoder.7 sigma = 0.9863
# Epoch 119: decoder.1 sigma = 1.0050
# Epoch 119: decoder.4 sigma = 1.0032
# Epoch 119/300, Training Loss: 0.0084, Validation Loss: 0.0094
# Epoch 120: encoder.1 sigma = 1.0120
# Epoch 120: encoder.4 sigma = 1.0000
# Epoch 120: encoder.7 sigma = 0.9860
# Epoch 120: decoder.1 sigma = 1.0050
# Epoch 120: decoder.4 sigma = 1.0033
# Epoch 120/300, Training Loss: 0.0084, Validation Loss: 0.0091
# Epoch 121: encoder.1 sigma = 1.0121
# Epoch 121: encoder.4 sigma = 1.0000
# Epoch 121: encoder.7 sigma = 0.9857
# Epoch 121: decoder.1 sigma = 1.0051
# Epoch 121: decoder.4 sigma = 1.0034
# Epoch 121/300, Training Loss: 0.0082, Validation Loss: 0.0090
# Epoch 122: encoder.1 sigma = 1.0123
# Epoch 122: encoder.4 sigma = 1.0000
# Epoch 122: encoder.7 sigma = 0.9855
# Epoch 122: decoder.1 sigma = 1.0053
# Epoch 122: decoder.4 sigma = 1.0035
# Epoch 122/300, Training Loss: 0.0082, Validation Loss: 0.0091
# Epoch 123: encoder.1 sigma = 1.0123
# Epoch 123: encoder.4 sigma = 1.0000
# Epoch 123: encoder.7 sigma = 0.9852
# Epoch 123: decoder.1 sigma = 1.0054
# Epoch 123: decoder.4 sigma = 1.0035
# Epoch 123/300, Training Loss: 0.0081, Validation Loss: 0.0094
# Epoch 124: encoder.1 sigma = 1.0125
# Epoch 124: encoder.4 sigma = 1.0000
# Epoch 124: encoder.7 sigma = 0.9849
# Epoch 124: decoder.1 sigma = 1.0055
# Epoch 124: decoder.4 sigma = 1.0037
# Epoch 124/300, Training Loss: 0.0082, Validation Loss: 0.0088
# Epoch 125: encoder.1 sigma = 1.0127
# Epoch 125: encoder.4 sigma = 1.0000
# Epoch 125: encoder.7 sigma = 0.9846
# Epoch 125: decoder.1 sigma = 1.0056
# Epoch 125: decoder.4 sigma = 1.0037
# Epoch 125/300, Training Loss: 0.0080, Validation Loss: 0.0087
# Epoch 126: encoder.1 sigma = 1.0127
# Epoch 126: encoder.4 sigma = 1.0000
# Epoch 126: encoder.7 sigma = 0.9843
# Epoch 126: decoder.1 sigma = 1.0057
# Epoch 126: decoder.4 sigma = 1.0038
# Epoch 126/300, Training Loss: 0.0078, Validation Loss: 0.0087
# Epoch 127: encoder.1 sigma = 1.0129
# Epoch 127: encoder.4 sigma = 1.0000
# Epoch 127: encoder.7 sigma = 0.9840
# Epoch 127: decoder.1 sigma = 1.0059
# Epoch 127: decoder.4 sigma = 1.0039
# Epoch 127/300, Training Loss: 0.0078, Validation Loss: 0.0087
# Epoch 128: encoder.1 sigma = 1.0130
# Epoch 128: encoder.4 sigma = 1.0000
# Epoch 128: encoder.7 sigma = 0.9837
# Epoch 128: decoder.1 sigma = 1.0060
# Epoch 128: decoder.4 sigma = 1.0040
# Epoch 128/300, Training Loss: 0.0078, Validation Loss: 0.0087
# Epoch 129: encoder.1 sigma = 1.0131
# Epoch 129: encoder.4 sigma = 1.0000
# Epoch 129: encoder.7 sigma = 0.9833
# Epoch 129: decoder.1 sigma = 1.0061
# Epoch 129: decoder.4 sigma = 1.0041
# Epoch 129/300, Training Loss: 0.0078, Validation Loss: 0.0084
# Epoch 130: encoder.1 sigma = 1.0133
# Epoch 130: encoder.4 sigma = 1.0000
# Epoch 130: encoder.7 sigma = 0.9830
# Epoch 130: decoder.1 sigma = 1.0063
# Epoch 130: decoder.4 sigma = 1.0042
# Epoch 130/300, Training Loss: 0.0076, Validation Loss: 0.0084
# Epoch 131: encoder.1 sigma = 1.0133
# Epoch 131: encoder.4 sigma = 1.0000
# Epoch 131: encoder.7 sigma = 0.9826
# Epoch 131: decoder.1 sigma = 1.0064
# Epoch 131: decoder.4 sigma = 1.0042
# Epoch 131/300, Training Loss: 0.0075, Validation Loss: 0.0084
# Epoch 132: encoder.1 sigma = 1.0135
# Epoch 132: encoder.4 sigma = 1.0000
# Epoch 132: encoder.7 sigma = 0.9823
# Epoch 132: decoder.1 sigma = 1.0065
# Epoch 132: decoder.4 sigma = 1.0043
# Epoch 132/300, Training Loss: 0.0077, Validation Loss: 0.0083
# Epoch 133: encoder.1 sigma = 1.0137
# Epoch 133: encoder.4 sigma = 1.0000
# Epoch 133: encoder.7 sigma = 0.9820
# Epoch 133: decoder.1 sigma = 1.0067
# Epoch 133: decoder.4 sigma = 1.0045
# Epoch 133/300, Training Loss: 0.0076, Validation Loss: 0.0089
# Epoch 134: encoder.1 sigma = 1.0137
# Epoch 134: encoder.4 sigma = 1.0000
# Epoch 134: encoder.7 sigma = 0.9815
# Epoch 134: decoder.1 sigma = 1.0068
# Epoch 134: decoder.4 sigma = 1.0045
# Epoch 134/300, Training Loss: 0.0079, Validation Loss: 0.0083
# Epoch 135: encoder.1 sigma = 1.0138
# Epoch 135: encoder.4 sigma = 1.0000
# Epoch 135: encoder.7 sigma = 0.9811
# Epoch 135: decoder.1 sigma = 1.0070
# Epoch 135: decoder.4 sigma = 1.0046
# Epoch 135/300, Training Loss: 0.0075, Validation Loss: 0.0081
# Epoch 136: encoder.1 sigma = 1.0140
# Epoch 136: encoder.4 sigma = 1.0001
# Epoch 136: encoder.7 sigma = 0.9806
# Epoch 136: decoder.1 sigma = 1.0071
# Epoch 136: decoder.4 sigma = 1.0047
# Epoch 136/300, Training Loss: 0.0073, Validation Loss: 0.0081
# Epoch 137: encoder.1 sigma = 1.0140
# Epoch 137: encoder.4 sigma = 1.0001
# Epoch 137: encoder.7 sigma = 0.9802
# Epoch 137: decoder.1 sigma = 1.0073
# Epoch 137: decoder.4 sigma = 1.0048
# Epoch 137/300, Training Loss: 0.0073, Validation Loss: 0.0081
# Epoch 138: encoder.1 sigma = 1.0142
# Epoch 138: encoder.4 sigma = 1.0001
# Epoch 138: encoder.7 sigma = 0.9798
# Epoch 138: decoder.1 sigma = 1.0075
# Epoch 138: decoder.4 sigma = 1.0049
# Epoch 138/300, Training Loss: 0.0072, Validation Loss: 0.0079
# Epoch 139: encoder.1 sigma = 1.0143
# Epoch 139: encoder.4 sigma = 1.0001
# Epoch 139: encoder.7 sigma = 0.9794
# Epoch 139: decoder.1 sigma = 1.0076
# Epoch 139: decoder.4 sigma = 1.0050
# Epoch 139/300, Training Loss: 0.0071, Validation Loss: 0.0078
# Epoch 140: encoder.1 sigma = 1.0144
# Epoch 140: encoder.4 sigma = 1.0001
# Epoch 140: encoder.7 sigma = 0.9789
# Epoch 140: decoder.1 sigma = 1.0078
# Epoch 140: decoder.4 sigma = 1.0051
# Epoch 140/300, Training Loss: 0.0070, Validation Loss: 0.0078
# Epoch 141: encoder.1 sigma = 1.0146
# Epoch 141: encoder.4 sigma = 1.0001
# Epoch 141: encoder.7 sigma = 0.9785
# Epoch 141: decoder.1 sigma = 1.0080
# Epoch 141: decoder.4 sigma = 1.0052
# Epoch 141/300, Training Loss: 0.0070, Validation Loss: 0.0077
# Epoch 142: encoder.1 sigma = 1.0147
# Epoch 142: encoder.4 sigma = 1.0000
# Epoch 142: encoder.7 sigma = 0.9781
# Epoch 142: decoder.1 sigma = 1.0082
# Epoch 142: decoder.4 sigma = 1.0053
# Epoch 142/300, Training Loss: 0.0069, Validation Loss: 0.0077
# Epoch 143: encoder.1 sigma = 1.0148
# Epoch 143: encoder.4 sigma = 1.0000
# Epoch 143: encoder.7 sigma = 0.9776
# Epoch 143: decoder.1 sigma = 1.0084
# Epoch 143: decoder.4 sigma = 1.0055
# Epoch 143/300, Training Loss: 0.0070, Validation Loss: 0.0076
# Epoch 144: encoder.1 sigma = 1.0150
# Epoch 144: encoder.4 sigma = 1.0000
# Epoch 144: encoder.7 sigma = 0.9772
# Epoch 144: decoder.1 sigma = 1.0086
# Epoch 144: decoder.4 sigma = 1.0056
# Epoch 144/300, Training Loss: 0.0068, Validation Loss: 0.0076
# Epoch 145: encoder.1 sigma = 1.0150
# Epoch 145: encoder.4 sigma = 1.0000
# Epoch 145: encoder.7 sigma = 0.9767
# Epoch 145: decoder.1 sigma = 1.0088
# Epoch 145: decoder.4 sigma = 1.0057
# Epoch 145/300, Training Loss: 0.0068, Validation Loss: 0.0075
# Epoch 146: encoder.1 sigma = 1.0152
# Epoch 146: encoder.4 sigma = 1.0000
# Epoch 146: encoder.7 sigma = 0.9762
# Epoch 146: decoder.1 sigma = 1.0090
# Epoch 146: decoder.4 sigma = 1.0058
# Epoch 146/300, Training Loss: 0.0067, Validation Loss: 0.0074
# Epoch 147: encoder.1 sigma = 1.0153
# Epoch 147: encoder.4 sigma = 1.0000
# Epoch 147: encoder.7 sigma = 0.9757
# Epoch 147: decoder.1 sigma = 1.0092
# Epoch 147: decoder.4 sigma = 1.0060
# Epoch 147/300, Training Loss: 0.0067, Validation Loss: 0.0074
# Epoch 148: encoder.1 sigma = 1.0154
# Epoch 148: encoder.4 sigma = 1.0000
# Epoch 148: encoder.7 sigma = 0.9752
# Epoch 148: decoder.1 sigma = 1.0095
# Epoch 148: decoder.4 sigma = 1.0061
# Epoch 148/300, Training Loss: 0.0067, Validation Loss: 0.0075
# Epoch 149: encoder.1 sigma = 1.0156
# Epoch 149: encoder.4 sigma = 1.0000
# Epoch 149: encoder.7 sigma = 0.9747
# Epoch 149: decoder.1 sigma = 1.0097
# Epoch 149: decoder.4 sigma = 1.0062
# Epoch 149/300, Training Loss: 0.0067, Validation Loss: 0.0073
# Epoch 150: encoder.1 sigma = 1.0157
# Epoch 150: encoder.4 sigma = 1.0000
# Epoch 150: encoder.7 sigma = 0.9741
# Epoch 150: decoder.1 sigma = 1.0099
# Epoch 150: decoder.4 sigma = 1.0064
# Epoch 150/300, Training Loss: 0.0066, Validation Loss: 0.0073
# Epoch 151: encoder.1 sigma = 1.0158
# Epoch 151: encoder.4 sigma = 1.0000
# Epoch 151: encoder.7 sigma = 0.9736
# Epoch 151: decoder.1 sigma = 1.0101
# Epoch 151: decoder.4 sigma = 1.0065
# Epoch 151/300, Training Loss: 0.0065, Validation Loss: 0.0073
# Epoch 152: encoder.1 sigma = 1.0160
# Epoch 152: encoder.4 sigma = 1.0000
# Epoch 152: encoder.7 sigma = 0.9730
# Epoch 152: decoder.1 sigma = 1.0104
# Epoch 152: decoder.4 sigma = 1.0067
# Epoch 152/300, Training Loss: 0.0065, Validation Loss: 0.0072
# Epoch 153: encoder.1 sigma = 1.0161
# Epoch 153: encoder.4 sigma = 1.0000
# Epoch 153: encoder.7 sigma = 0.9724
# Epoch 153: decoder.1 sigma = 1.0106
# Epoch 153: decoder.4 sigma = 1.0068
# Epoch 153/300, Training Loss: 0.0065, Validation Loss: 0.0072
# Epoch 154: encoder.1 sigma = 1.0162
# Epoch 154: encoder.4 sigma = 1.0000
# Epoch 154: encoder.7 sigma = 0.9718
# Epoch 154: decoder.1 sigma = 1.0109
# Epoch 154: decoder.4 sigma = 1.0070
# Epoch 154/300, Training Loss: 0.0064, Validation Loss: 0.0072
# Epoch 155: encoder.1 sigma = 1.0164
# Epoch 155: encoder.4 sigma = 1.0000
# Epoch 155: encoder.7 sigma = 0.9711
# Epoch 155: decoder.1 sigma = 1.0112
# Epoch 155: decoder.4 sigma = 1.0071
# Epoch 155/300, Training Loss: 0.0064, Validation Loss: 0.0072
# Epoch 156: encoder.1 sigma = 1.0165
# Epoch 156: encoder.4 sigma = 1.0000
# Epoch 156: encoder.7 sigma = 0.9705
# Epoch 156: decoder.1 sigma = 1.0114
# Epoch 156: decoder.4 sigma = 1.0073
# Epoch 156/300, Training Loss: 0.0065, Validation Loss: 0.0070
# Epoch 157: encoder.1 sigma = 1.0165
# Epoch 157: encoder.4 sigma = 0.9999
# Epoch 157: encoder.7 sigma = 0.9697
# Epoch 157: decoder.1 sigma = 1.0117
# Epoch 157: decoder.4 sigma = 1.0074
# Epoch 157/300, Training Loss: 0.0064, Validation Loss: 0.0076
# Epoch 158: encoder.1 sigma = 1.0167
# Epoch 158: encoder.4 sigma = 1.0000
# Epoch 158: encoder.7 sigma = 0.9690
# Epoch 158: decoder.1 sigma = 1.0120
# Epoch 158: decoder.4 sigma = 1.0076
# Epoch 158/300, Training Loss: 0.0065, Validation Loss: 0.0071
# Epoch 159: encoder.1 sigma = 1.0168
# Epoch 159: encoder.4 sigma = 1.0000
# Epoch 159: encoder.7 sigma = 0.9683
# Epoch 159: decoder.1 sigma = 1.0123
# Epoch 159: decoder.4 sigma = 1.0077
# Epoch 159/300, Training Loss: 0.0066, Validation Loss: 0.0070
# Epoch 160: encoder.1 sigma = 1.0168
# Epoch 160: encoder.4 sigma = 0.9999
# Epoch 160: encoder.7 sigma = 0.9674
# Epoch 160: decoder.1 sigma = 1.0125
# Epoch 160: decoder.4 sigma = 1.0078
# Epoch 160/300, Training Loss: 0.0064, Validation Loss: 0.0076
# Epoch 161: encoder.1 sigma = 1.0170
# Epoch 161: encoder.4 sigma = 0.9999
# Epoch 161: encoder.7 sigma = 0.9667
# Epoch 161: decoder.1 sigma = 1.0129
# Epoch 161: decoder.4 sigma = 1.0080
# Epoch 161/300, Training Loss: 0.0064, Validation Loss: 0.0074
# Epoch 162: encoder.1 sigma = 1.0169
# Epoch 162: encoder.4 sigma = 0.9999
# Epoch 162: encoder.7 sigma = 0.9658
# Epoch 162: decoder.1 sigma = 1.0131
# Epoch 162: decoder.4 sigma = 1.0081
# Epoch 162/300, Training Loss: 0.0064, Validation Loss: 0.0074
# Epoch 163: encoder.1 sigma = 1.0171
# Epoch 163: encoder.4 sigma = 1.0000
# Epoch 163: encoder.7 sigma = 0.9651
# Epoch 163: decoder.1 sigma = 1.0134
# Epoch 163: decoder.4 sigma = 1.0083
# Epoch 163/300, Training Loss: 0.0063, Validation Loss: 0.0071
# Epoch 164: encoder.1 sigma = 1.0171
# Epoch 164: encoder.4 sigma = 1.0000
# Epoch 164: encoder.7 sigma = 0.9641
# Epoch 164: decoder.1 sigma = 1.0137
# Epoch 164: decoder.4 sigma = 1.0084
# Epoch 164/300, Training Loss: 0.0063, Validation Loss: 0.0070
# Epoch 165: encoder.1 sigma = 1.0172
# Epoch 165: encoder.4 sigma = 1.0000
# Epoch 165: encoder.7 sigma = 0.9634
# Epoch 165: decoder.1 sigma = 1.0140
# Epoch 165: decoder.4 sigma = 1.0086
# Epoch 165/300, Training Loss: 0.0062, Validation Loss: 0.0069
# Epoch 166: encoder.1 sigma = 1.0172
# Epoch 166: encoder.4 sigma = 0.9999
# Epoch 166: encoder.7 sigma = 0.9625
# Epoch 166: decoder.1 sigma = 1.0143
# Epoch 166: decoder.4 sigma = 1.0087
# Epoch 166/300, Training Loss: 0.0061, Validation Loss: 0.0070
# Epoch 167: encoder.1 sigma = 1.0174
# Epoch 167: encoder.4 sigma = 1.0000
# Epoch 167: encoder.7 sigma = 0.9617
# Epoch 167: decoder.1 sigma = 1.0147
# Epoch 167: decoder.4 sigma = 1.0089
# Epoch 167/300, Training Loss: 0.0062, Validation Loss: 0.0068
# Epoch 168: encoder.1 sigma = 1.0174
# Epoch 168: encoder.4 sigma = 1.0000
# Epoch 168: encoder.7 sigma = 0.9608
# Epoch 168: decoder.1 sigma = 1.0149
# Epoch 168: decoder.4 sigma = 1.0090
# Epoch 168/300, Training Loss: 0.0061, Validation Loss: 0.0068
# Epoch 169: encoder.1 sigma = 1.0176
# Epoch 169: encoder.4 sigma = 1.0001
# Epoch 169: encoder.7 sigma = 0.9600
# Epoch 169: decoder.1 sigma = 1.0153
# Epoch 169: decoder.4 sigma = 1.0092
# Epoch 169/300, Training Loss: 0.0060, Validation Loss: 0.0067
# Epoch 170: encoder.1 sigma = 1.0177
# Epoch 170: encoder.4 sigma = 1.0001
# Epoch 170: encoder.7 sigma = 0.9591
# Epoch 170: decoder.1 sigma = 1.0156
# Epoch 170: decoder.4 sigma = 1.0094
# Epoch 170/300, Training Loss: 0.0061, Validation Loss: 0.0069
# Epoch 171: encoder.1 sigma = 1.0177
# Epoch 171: encoder.4 sigma = 1.0001
# Epoch 171: encoder.7 sigma = 0.9583
# Epoch 171: decoder.1 sigma = 1.0159
# Epoch 171: decoder.4 sigma = 1.0096
# Epoch 171/300, Training Loss: 0.0061, Validation Loss: 0.0068
# Epoch 172: encoder.1 sigma = 1.0178
# Epoch 172: encoder.4 sigma = 1.0000
# Epoch 172: encoder.7 sigma = 0.9574
# Epoch 172: decoder.1 sigma = 1.0162
# Epoch 172: decoder.4 sigma = 1.0097
# Epoch 172/300, Training Loss: 0.0061, Validation Loss: 0.0066
# Epoch 173: encoder.1 sigma = 1.0179
# Epoch 173: encoder.4 sigma = 1.0000
# Epoch 173: encoder.7 sigma = 0.9565
# Epoch 173: decoder.1 sigma = 1.0166
# Epoch 173: decoder.4 sigma = 1.0099
# Epoch 173/300, Training Loss: 0.0059, Validation Loss: 0.0065
# Epoch 174: encoder.1 sigma = 1.0180
# Epoch 174: encoder.4 sigma = 0.9999
# Epoch 174: encoder.7 sigma = 0.9556
# Epoch 174: decoder.1 sigma = 1.0169
# Epoch 174: decoder.4 sigma = 1.0101
# Epoch 174/300, Training Loss: 0.0059, Validation Loss: 0.0064
# Epoch 175: encoder.1 sigma = 1.0180
# Epoch 175: encoder.4 sigma = 1.0000
# Epoch 175: encoder.7 sigma = 0.9548
# Epoch 175: decoder.1 sigma = 1.0172
# Epoch 175: decoder.4 sigma = 1.0102
# Epoch 175/300, Training Loss: 0.0058, Validation Loss: 0.0064
# Epoch 176: encoder.1 sigma = 1.0181
# Epoch 176: encoder.4 sigma = 1.0000
# Epoch 176: encoder.7 sigma = 0.9538
# Epoch 176: decoder.1 sigma = 1.0175
# Epoch 176: decoder.4 sigma = 1.0104
# Epoch 176/300, Training Loss: 0.0058, Validation Loss: 0.0064
# Epoch 177: encoder.1 sigma = 1.0183
# Epoch 177: encoder.4 sigma = 1.0001
# Epoch 177: encoder.7 sigma = 0.9530
# Epoch 177: decoder.1 sigma = 1.0179
# Epoch 177: decoder.4 sigma = 1.0106
# Epoch 177/300, Training Loss: 0.0057, Validation Loss: 0.0064
# Epoch 178: encoder.1 sigma = 1.0183
# Epoch 178: encoder.4 sigma = 1.0001
# Epoch 178: encoder.7 sigma = 0.9521
# Epoch 178: decoder.1 sigma = 1.0182
# Epoch 178: decoder.4 sigma = 1.0108
# Epoch 178/300, Training Loss: 0.0057, Validation Loss: 0.0066
# Epoch 179: encoder.1 sigma = 1.0185
# Epoch 179: encoder.4 sigma = 1.0002
# Epoch 179: encoder.7 sigma = 0.9512
# Epoch 179: decoder.1 sigma = 1.0186
# Epoch 179: decoder.4 sigma = 1.0110
# Epoch 179/300, Training Loss: 0.0057, Validation Loss: 0.0065
# Epoch 180: encoder.1 sigma = 1.0185
# Epoch 180: encoder.4 sigma = 1.0001
# Epoch 180: encoder.7 sigma = 0.9502
# Epoch 180: decoder.1 sigma = 1.0189
# Epoch 180: decoder.4 sigma = 1.0112
# Epoch 180/300, Training Loss: 0.0059, Validation Loss: 0.0063
# Epoch 181: encoder.1 sigma = 1.0186
# Epoch 181: encoder.4 sigma = 1.0001
# Epoch 181: encoder.7 sigma = 0.9494
# Epoch 181: decoder.1 sigma = 1.0193
# Epoch 181: decoder.4 sigma = 1.0114
# Epoch 181/300, Training Loss: 0.0057, Validation Loss: 0.0065
# Epoch 182: encoder.1 sigma = 1.0187
# Epoch 182: encoder.4 sigma = 1.0000
# Epoch 182: encoder.7 sigma = 0.9484
# Epoch 182: decoder.1 sigma = 1.0197
# Epoch 182: decoder.4 sigma = 1.0116
# Epoch 182/300, Training Loss: 0.0057, Validation Loss: 0.0063
# Epoch 183: encoder.1 sigma = 1.0188
# Epoch 183: encoder.4 sigma = 1.0000
# Epoch 183: encoder.7 sigma = 0.9475
# Epoch 183: decoder.1 sigma = 1.0200
# Epoch 183: decoder.4 sigma = 1.0118
# Epoch 183/300, Training Loss: 0.0057, Validation Loss: 0.0062
# Epoch 184: encoder.1 sigma = 1.0189
# Epoch 184: encoder.4 sigma = 0.9999
# Epoch 184: encoder.7 sigma = 0.9465
# Epoch 184: decoder.1 sigma = 1.0204
# Epoch 184: decoder.4 sigma = 1.0120
# Epoch 184/300, Training Loss: 0.0056, Validation Loss: 0.0062
# Epoch 185: encoder.1 sigma = 1.0191
# Epoch 185: encoder.4 sigma = 1.0000
# Epoch 185: encoder.7 sigma = 0.9455
# Epoch 185: decoder.1 sigma = 1.0208
# Epoch 185: decoder.4 sigma = 1.0123
# Epoch 185/300, Training Loss: 0.0056, Validation Loss: 0.0062
# Epoch 186: encoder.1 sigma = 1.0191
# Epoch 186: encoder.4 sigma = 1.0000
# Epoch 186: encoder.7 sigma = 0.9444
# Epoch 186: decoder.1 sigma = 1.0212
# Epoch 186: decoder.4 sigma = 1.0125
# Epoch 186/300, Training Loss: 0.0056, Validation Loss: 0.0061
# Epoch 187: encoder.1 sigma = 1.0192
# Epoch 187: encoder.4 sigma = 1.0001
# Epoch 187: encoder.7 sigma = 0.9435
# Epoch 187: decoder.1 sigma = 1.0217
# Epoch 187: decoder.4 sigma = 1.0127
# Epoch 187/300, Training Loss: 0.0055, Validation Loss: 0.0061
# Epoch 188: encoder.1 sigma = 1.0193
# Epoch 188: encoder.4 sigma = 1.0001
# Epoch 188: encoder.7 sigma = 0.9424
# Epoch 188: decoder.1 sigma = 1.0221
# Epoch 188: decoder.4 sigma = 1.0129
# Epoch 188/300, Training Loss: 0.0054, Validation Loss: 0.0061
# Epoch 189: encoder.1 sigma = 1.0195
# Epoch 189: encoder.4 sigma = 1.0001
# Epoch 189: encoder.7 sigma = 0.9413
# Epoch 189: decoder.1 sigma = 1.0225
# Epoch 189: decoder.4 sigma = 1.0132
# Epoch 189/300, Training Loss: 0.0054, Validation Loss: 0.0062
# Epoch 190: encoder.1 sigma = 1.0196
# Epoch 190: encoder.4 sigma = 1.0001
# Epoch 190: encoder.7 sigma = 0.9402
# Epoch 190: decoder.1 sigma = 1.0230
# Epoch 190: decoder.4 sigma = 1.0134
# Epoch 190/300, Training Loss: 0.0056, Validation Loss: 0.0060
# Epoch 191: encoder.1 sigma = 1.0196
# Epoch 191: encoder.4 sigma = 1.0000
# Epoch 191: encoder.7 sigma = 0.9390
# Epoch 191: decoder.1 sigma = 1.0234
# Epoch 191: decoder.4 sigma = 1.0136
# Epoch 191/300, Training Loss: 0.0055, Validation Loss: 0.0064
# Epoch 192: encoder.1 sigma = 1.0198
# Epoch 192: encoder.4 sigma = 1.0000
# Epoch 192: encoder.7 sigma = 0.9379
# Epoch 192: decoder.1 sigma = 1.0239
# Epoch 192: decoder.4 sigma = 1.0139
# Epoch 192/300, Training Loss: 0.0057, Validation Loss: 0.0060
# Epoch 193: encoder.1 sigma = 1.0199
# Epoch 193: encoder.4 sigma = 1.0000
# Epoch 193: encoder.7 sigma = 0.9366
# Epoch 193: decoder.1 sigma = 1.0244
# Epoch 193: decoder.4 sigma = 1.0141
# Epoch 193/300, Training Loss: 0.0054, Validation Loss: 0.0062
# Epoch 194: encoder.1 sigma = 1.0199
# Epoch 194: encoder.4 sigma = 1.0000
# Epoch 194: encoder.7 sigma = 0.9354
# Epoch 194: decoder.1 sigma = 1.0248
# Epoch 194: decoder.4 sigma = 1.0143
# Epoch 194/300, Training Loss: 0.0055, Validation Loss: 0.0059
# Epoch 195: encoder.1 sigma = 1.0200
# Epoch 195: encoder.4 sigma = 1.0000
# Epoch 195: encoder.7 sigma = 0.9341
# Epoch 195: decoder.1 sigma = 1.0253
# Epoch 195: decoder.4 sigma = 1.0145
# Epoch 195/300, Training Loss: 0.0053, Validation Loss: 0.0060
# Epoch 196: encoder.1 sigma = 1.0201
# Epoch 196: encoder.4 sigma = 1.0001
# Epoch 196: encoder.7 sigma = 0.9329
# Epoch 196: decoder.1 sigma = 1.0258
# Epoch 196: decoder.4 sigma = 1.0148
# Epoch 196/300, Training Loss: 0.0053, Validation Loss: 0.0059
# Epoch 197: encoder.1 sigma = 1.0202
# Epoch 197: encoder.4 sigma = 1.0001
# Epoch 197: encoder.7 sigma = 0.9316
# Epoch 197: decoder.1 sigma = 1.0263
# Epoch 197: decoder.4 sigma = 1.0150
# Epoch 197/300, Training Loss: 0.0053, Validation Loss: 0.0059
# Epoch 198: encoder.1 sigma = 1.0203
# Epoch 198: encoder.4 sigma = 1.0001
# Epoch 198: encoder.7 sigma = 0.9303
# Epoch 198: decoder.1 sigma = 1.0268
# Epoch 198: decoder.4 sigma = 1.0153
# Epoch 198/300, Training Loss: 0.0053, Validation Loss: 0.0058
# Epoch 199: encoder.1 sigma = 1.0204
# Epoch 199: encoder.4 sigma = 1.0001
# Epoch 199: encoder.7 sigma = 0.9290
# Epoch 199: decoder.1 sigma = 1.0273
# Epoch 199: decoder.4 sigma = 1.0155
# Epoch 199/300, Training Loss: 0.0053, Validation Loss: 0.0058
# Epoch 200: encoder.1 sigma = 1.0205
# Epoch 200: encoder.4 sigma = 1.0000
# Epoch 200: encoder.7 sigma = 0.9278
# Epoch 200: decoder.1 sigma = 1.0278
# Epoch 200: decoder.4 sigma = 1.0158
# Epoch 200/300, Training Loss: 0.0052, Validation Loss: 0.0057
# Epoch 201: encoder.1 sigma = 1.0206
# Epoch 201: encoder.4 sigma = 1.0000
# Epoch 201: encoder.7 sigma = 0.9265
# Epoch 201: decoder.1 sigma = 1.0283
# Epoch 201: decoder.4 sigma = 1.0160
# Epoch 201/300, Training Loss: 0.0052, Validation Loss: 0.0057
# ...
# Epoch 235: encoder.1 sigma = 1.0225
# Epoch 235: encoder.4 sigma = 1.0000
# Epoch 235: encoder.7 sigma = 0.8894
# Epoch 235: decoder.1 sigma = 1.0432
# Epoch 235: decoder.4 sigma = 1.0234
# Epoch 235/300, Training Loss: 0.0050, Validation Loss: 0.0059
# Epoch 236: encoder.1 sigma = 1.0226
# Epoch 236: encoder.4 sigma = 1.0000
# Epoch 236: encoder.7 sigma = 0.8884
# Epoch 236: decoder.1 sigma = 1.0436
# Epoch 236: decoder.4 sigma = 1.0236
# Epoch 236/300, Training Loss: 0.0056, Validation Loss: 0.0057
# Epoch 237: encoder.1 sigma = 1.0226
# Epoch 237: encoder.4 sigma = 0.9999
# Epoch 237: encoder.7 sigma = 0.8872
# Epoch 237: decoder.1 sigma = 1.0438
# Epoch 237: decoder.4 sigma = 1.0236
# Epoch 237/300, Training Loss: 0.0049, Validation Loss: 0.0057
# Epoch 238: encoder.1 sigma = 1.0225
# Epoch 238: encoder.4 sigma = 0.9999
# Epoch 238: encoder.7 sigma = 0.8864
# Epoch 238: decoder.1 sigma = 1.0441
# Epoch 238: decoder.4 sigma = 1.0237
# Epoch 238/300, Training Loss: 0.0051, Validation Loss: 0.0054
# Epoch 239: encoder.1 sigma = 1.0226
# Epoch 239: encoder.4 sigma = 1.0000
# Epoch 239: encoder.7 sigma = 0.8853
# Epoch 239: decoder.1 sigma = 1.0445
# Epoch 239: decoder.4 sigma = 1.0239
# Epoch 239/300, Training Loss: 0.0049, Validation Loss: 0.0058
# Epoch 240: encoder.1 sigma = 1.0224
# Epoch 240: encoder.4 sigma = 1.0000
# Epoch 240: encoder.7 sigma = 0.8847
# Epoch 240: decoder.1 sigma = 1.0447
# Epoch 240: decoder.4 sigma = 1.0239
# Epoch 240/300, Training Loss: 0.0049, Validation Loss: 0.0055
# Epoch 241: encoder.1 sigma = 1.0226
# Epoch 241: encoder.4 sigma = 1.0001
# Epoch 241: encoder.7 sigma = 0.8838
# Epoch 241: decoder.1 sigma = 1.0451
# Epoch 241: decoder.4 sigma = 1.0241
# Epoch 241/300, Training Loss: 0.0048, Validation Loss: 0.0052
# Epoch 242: encoder.1 sigma = 1.0226
# Epoch 242: encoder.4 sigma = 1.0002
# Epoch 242: encoder.7 sigma = 0.8832
# Epoch 242: decoder.1 sigma = 1.0454
# Epoch 242: decoder.4 sigma = 1.0243
# Epoch 242/300, Training Loss: 0.0047, Validation Loss: 0.0051
# Epoch 243: encoder.1 sigma = 1.0226
# Epoch 243: encoder.4 sigma = 1.0003
# Epoch 243: encoder.7 sigma = 0.8825
# Epoch 243: decoder.1 sigma = 1.0458
# Epoch 243: decoder.4 sigma = 1.0245
# Epoch 243/300, Training Loss: 0.0046, Validation Loss: 0.0051
# Epoch 244: encoder.1 sigma = 1.0227
# Epoch 244: encoder.4 sigma = 1.0004
# Epoch 244: encoder.7 sigma = 0.8818
# Epoch 244: decoder.1 sigma = 1.0461
# Epoch 244: decoder.4 sigma = 1.0247
# Epoch 244/300, Training Loss: 0.0046, Validation Loss: 0.0051
# Epoch 245: encoder.1 sigma = 1.0227
# Epoch 245: encoder.4 sigma = 1.0004
# Epoch 245: encoder.7 sigma = 0.8811
# Epoch 245: decoder.1 sigma = 1.0465
# Epoch 245: decoder.4 sigma = 1.0250
# Epoch 245/300, Training Loss: 0.0046, Validation Loss: 0.0051
# Epoch 246: encoder.1 sigma = 1.0229
# Epoch 246: encoder.4 sigma = 1.0005
# Epoch 246: encoder.7 sigma = 0.8804
# Epoch 246: decoder.1 sigma = 1.0469
# Epoch 246: decoder.4 sigma = 1.0252
# Epoch 246/300, Training Loss: 0.0045, Validation Loss: 0.0050
# Epoch 247: encoder.1 sigma = 1.0230
# Epoch 247: encoder.4 sigma = 1.0005
# Epoch 247: encoder.7 sigma = 0.8796
# Epoch 247: decoder.1 sigma = 1.0473
# Epoch 247: decoder.4 sigma = 1.0255
# Epoch 247/300, Training Loss: 0.0045, Validation Loss: 0.0050
# Epoch 248: encoder.1 sigma = 1.0230
# Epoch 248: encoder.4 sigma = 1.0006
# Epoch 248: encoder.7 sigma = 0.8790
# Epoch 248: decoder.1 sigma = 1.0477
# Epoch 248: decoder.4 sigma = 1.0258
# Epoch 248/300, Training Loss: 0.0044, Validation Loss: 0.0050
# Epoch 249: encoder.1 sigma = 1.0231
# Epoch 249: encoder.4 sigma = 1.0006
# Epoch 249: encoder.7 sigma = 0.8781
# Epoch 249: decoder.1 sigma = 1.0482
# Epoch 249: decoder.4 sigma = 1.0260
# Epoch 249/300, Training Loss: 0.0044, Validation Loss: 0.0049
# Epoch 250: encoder.1 sigma = 1.0233
# Epoch 250: encoder.4 sigma = 1.0006
# Epoch 250: encoder.7 sigma = 0.8772
# Epoch 250: decoder.1 sigma = 1.0486
# Epoch 250: decoder.4 sigma = 1.0263
# Epoch 250/300, Training Loss: 0.0044, Validation Loss: 0.0049
# Epoch 251: encoder.1 sigma = 1.0233
# Epoch 251: encoder.4 sigma = 1.0005
# Epoch 251: encoder.7 sigma = 0.8763
# Epoch 251: decoder.1 sigma = 1.0490
# Epoch 251: decoder.4 sigma = 1.0265
# Epoch 251/300, Training Loss: 0.0044, Validation Loss: 0.0049
# Epoch 252: encoder.1 sigma = 1.0234
# Epoch 252: encoder.4 sigma = 1.0005
# Epoch 252: encoder.7 sigma = 0.8754
# Epoch 252: decoder.1 sigma = 1.0495
# Epoch 252: decoder.4 sigma = 1.0268
# Epoch 252/300, Training Loss: 0.0044, Validation Loss: 0.0049
# Epoch 253: encoder.1 sigma = 1.0235
# Epoch 253: encoder.4 sigma = 1.0004
# Epoch 253: encoder.7 sigma = 0.8744
# Epoch 253: decoder.1 sigma = 1.0499
# Epoch 253: decoder.4 sigma = 1.0270
# Epoch 253/300, Training Loss: 0.0043, Validation Loss: 0.0048
# Epoch 254: encoder.1 sigma = 1.0236
# Epoch 254: encoder.4 sigma = 1.0004
# Epoch 254: encoder.7 sigma = 0.8734
# Epoch 254: decoder.1 sigma = 1.0504
# Epoch 254: decoder.4 sigma = 1.0273
# Epoch 254/300, Training Loss: 0.0043, Validation Loss: 0.0048
# Epoch 255: encoder.1 sigma = 1.0237
# Epoch 255: encoder.4 sigma = 1.0004
# Epoch 255: encoder.7 sigma = 0.8724
# Epoch 255: decoder.1 sigma = 1.0508
# Epoch 255: decoder.4 sigma = 1.0275
# Epoch 255/300, Training Loss: 0.0043, Validation Loss: 0.0049
# Epoch 256: encoder.1 sigma = 1.0238
# Epoch 256: encoder.4 sigma = 1.0003
# Epoch 256: encoder.7 sigma = 0.8713
# Epoch 256: decoder.1 sigma = 1.0513
# Epoch 256: decoder.4 sigma = 1.0278
# Epoch 256/300, Training Loss: 0.0047, Validation Loss: 0.0069
# Epoch 257: encoder.1 sigma = 1.0238
# Epoch 257: encoder.4 sigma = 0.9999
# Epoch 257: encoder.7 sigma = 0.8703
# Epoch 257: decoder.1 sigma = 1.0516
# Epoch 257: decoder.4 sigma = 1.0278
# Epoch 257/300, Training Loss: 0.0075, Validation Loss: 0.0066
# Epoch 258: encoder.1 sigma = 1.0236
# Epoch 258: encoder.4 sigma = 0.9995
# Epoch 258: encoder.7 sigma = 0.8699
# Epoch 258: decoder.1 sigma = 1.0517
# Epoch 258: decoder.4 sigma = 1.0277
# Epoch 258/300, Training Loss: 0.0070, Validation Loss: 0.0067
# Epoch 259: encoder.1 sigma = 1.0230
# Epoch 259: encoder.4 sigma = 0.9989
# Epoch 259: encoder.7 sigma = 0.8694
# Epoch 259: decoder.1 sigma = 1.0515
# Epoch 259: decoder.4 sigma = 1.0273
# Epoch 259/300, Training Loss: 0.0066, Validation Loss: 0.0056
# Epoch 260: encoder.1 sigma = 1.0225
# Epoch 260: encoder.4 sigma = 0.9984
# Epoch 260: encoder.7 sigma = 0.8688
# Epoch 260: decoder.1 sigma = 1.0513
# Epoch 260: decoder.4 sigma = 1.0269
# Epoch 260/300, Training Loss: 0.0052, Validation Loss: 0.0069
# Epoch 261: encoder.1 sigma = 1.0223
# Epoch 261: encoder.4 sigma = 0.9983
# Epoch 261: encoder.7 sigma = 0.8686
# Epoch 261: decoder.1 sigma = 1.0514
# Epoch 261: decoder.4 sigma = 1.0270
# Epoch 261/300, Training Loss: 0.0058, Validation Loss: 0.0062
# Epoch 262: encoder.1 sigma = 1.0219
# Epoch 262: encoder.4 sigma = 0.9980
# Epoch 262: encoder.7 sigma = 0.8682
# Epoch 262: decoder.1 sigma = 1.0514
# Epoch 262: decoder.4 sigma = 1.0268
# Epoch 262/300, Training Loss: 0.0058, Validation Loss: 0.0061
# Epoch 263: encoder.1 sigma = 1.0217
# Epoch 263: encoder.4 sigma = 0.9979
# Epoch 263: encoder.7 sigma = 0.8679
# Epoch 263: decoder.1 sigma = 1.0514
# Epoch 263: decoder.4 sigma = 1.0268
# Epoch 263/300, Training Loss: 0.0055, Validation Loss: 0.0058
# Epoch 264: encoder.1 sigma = 1.0217
# Epoch 264: encoder.4 sigma = 0.9981
# Epoch 264: encoder.7 sigma = 0.8677
# Epoch 264: decoder.1 sigma = 1.0517
# Epoch 264: decoder.4 sigma = 1.0270
# Epoch 264/300, Training Loss: 0.0051, Validation Loss: 0.0058
# Epoch 265: encoder.1 sigma = 1.0215
# Epoch 265: encoder.4 sigma = 0.9981
# Epoch 265: encoder.7 sigma = 0.8674
# Epoch 265: decoder.1 sigma = 1.0519
# Epoch 265: decoder.4 sigma = 1.0270
# Epoch 265/300, Training Loss: 0.0051, Validation Loss: 0.0056
# Epoch 266: encoder.1 sigma = 1.0216
# Epoch 266: encoder.4 sigma = 0.9981
# Epoch 266: encoder.7 sigma = 0.8670
# Epoch 266: decoder.1 sigma = 1.0521
# Epoch 266: decoder.4 sigma = 1.0271
# Epoch 266/300, Training Loss: 0.0049, Validation Loss: 0.0057
# Epoch 267: encoder.1 sigma = 1.0215
# Epoch 267: encoder.4 sigma = 0.9982
# Epoch 267: encoder.7 sigma = 0.8668
# Epoch 267: decoder.1 sigma = 1.0523
# Epoch 267: decoder.4 sigma = 1.0272
# Epoch 267/300, Training Loss: 0.0051, Validation Loss: 0.0052
# Epoch 268: encoder.1 sigma = 1.0215
# Epoch 268: encoder.4 sigma = 0.9984
# Epoch 268: encoder.7 sigma = 0.8666
# Epoch 268: decoder.1 sigma = 1.0526
# Epoch 268: decoder.4 sigma = 1.0274
# Epoch 268/300, Training Loss: 0.0047, Validation Loss: 0.0053
# Epoch 269: encoder.1 sigma = 1.0214
# Epoch 269: encoder.4 sigma = 0.9985
# Epoch 269: encoder.7 sigma = 0.8662
# Epoch 269: decoder.1 sigma = 1.0528
# Epoch 269: decoder.4 sigma = 1.0275
# Epoch 269/300, Training Loss: 0.0048, Validation Loss: 0.0052
# Epoch 270: encoder.1 sigma = 1.0214
# Epoch 270: encoder.4 sigma = 0.9986
# Epoch 270: encoder.7 sigma = 0.8659
# Epoch 270: decoder.1 sigma = 1.0530
# Epoch 270: decoder.4 sigma = 1.0275
# Epoch 270/300, Training Loss: 0.0047, Validation Loss: 0.0054
# Epoch 271: encoder.1 sigma = 1.0214
# Epoch 271: encoder.4 sigma = 0.9987
# Epoch 271: encoder.7 sigma = 0.8657
# Epoch 271: decoder.1 sigma = 1.0532
# Epoch 271: decoder.4 sigma = 1.0277
# Epoch 271/300, Training Loss: 0.0047, Validation Loss: 0.0052
# Epoch 272: encoder.1 sigma = 1.0214
# Epoch 272: encoder.4 sigma = 0.9988
# Epoch 272: encoder.7 sigma = 0.8654
# Epoch 272: decoder.1 sigma = 1.0535
# Epoch 272: decoder.4 sigma = 1.0278
# Epoch 272/300, Training Loss: 0.0047, Validation Loss: 0.0051
# Epoch 273: encoder.1 sigma = 1.0213
# Epoch 273: encoder.4 sigma = 0.9989
# Epoch 273: encoder.7 sigma = 0.8650
# Epoch 273: decoder.1 sigma = 1.0537
# Epoch 273: decoder.4 sigma = 1.0278
# Epoch 273/300, Training Loss: 0.0046, Validation Loss: 0.0051
# Epoch 274: encoder.1 sigma = 1.0213
# Epoch 274: encoder.4 sigma = 0.9990
# Epoch 274: encoder.7 sigma = 0.8648
# Epoch 274: decoder.1 sigma = 1.0539
# Epoch 274: decoder.4 sigma = 1.0279
# Epoch 274/300, Training Loss: 0.0046, Validation Loss: 0.0050
# Epoch 275: encoder.1 sigma = 1.0214
# Epoch 275: encoder.4 sigma = 0.9992
# Epoch 275: encoder.7 sigma = 0.8645
# Epoch 275: decoder.1 sigma = 1.0542
# Epoch 275: decoder.4 sigma = 1.0281
# Epoch 275/300, Training Loss: 0.0045, Validation Loss: 0.0050
# Epoch 276: encoder.1 sigma = 1.0213
# Epoch 276: encoder.4 sigma = 0.9993
# Epoch 276: encoder.7 sigma = 0.8642
# Epoch 276: decoder.1 sigma = 1.0543
# Epoch 276: decoder.4 sigma = 1.0281
# Epoch 276/300, Training Loss: 0.0045, Validation Loss: 0.0050
# Epoch 277: encoder.1 sigma = 1.0214
# Epoch 277: encoder.4 sigma = 0.9994
# Epoch 277: encoder.7 sigma = 0.8639
# Epoch 277: decoder.1 sigma = 1.0546
# Epoch 277: decoder.4 sigma = 1.0282
# Epoch 277/300, Training Loss: 0.0045, Validation Loss: 0.0050
# Epoch 278: encoder.1 sigma = 1.0214
# Epoch 278: encoder.4 sigma = 0.9996
# Epoch 278: encoder.7 sigma = 0.8636
# Epoch 278: decoder.1 sigma = 1.0549
# Epoch 278: decoder.4 sigma = 1.0284
# Epoch 278/300, Training Loss: 0.0045, Validation Loss: 0.0049
# Epoch 279: encoder.1 sigma = 1.0215
# Epoch 279: encoder.4 sigma = 0.9998
# Epoch 279: encoder.7 sigma = 0.8634
# Epoch 279: decoder.1 sigma = 1.0551
# Epoch 279: decoder.4 sigma = 1.0286
# Epoch 279/300, Training Loss: 0.0044, Validation Loss: 0.0049
# Epoch 280: encoder.1 sigma = 1.0215
# Epoch 280: encoder.4 sigma = 1.0000
# Epoch 280: encoder.7 sigma = 0.8631
# Epoch 280: decoder.1 sigma = 1.0554
# Epoch 280: decoder.4 sigma = 1.0287
# Epoch 280/300, Training Loss: 0.0044, Validation Loss: 0.0050
# Epoch 281: encoder.1 sigma = 1.0217
# Epoch 281: encoder.4 sigma = 1.0002
# Epoch 281: encoder.7 sigma = 0.8628
# Epoch 281: decoder.1 sigma = 1.0557
# Epoch 281: decoder.4 sigma = 1.0290
# Epoch 281/300, Training Loss: 0.0044, Validation Loss: 0.0050
# Epoch 282: encoder.1 sigma = 1.0217
# Epoch 282: encoder.4 sigma = 1.0003
# Epoch 282: encoder.7 sigma = 0.8626
# Epoch 282: decoder.1 sigma = 1.0560
# Epoch 282: decoder.4 sigma = 1.0291
# Epoch 282/300, Training Loss: 0.0044, Validation Loss: 0.0050
# Epoch 283: encoder.1 sigma = 1.0218
# Epoch 283: encoder.4 sigma = 1.0004
# Epoch 283: encoder.7 sigma = 0.8623
# Epoch 283: decoder.1 sigma = 1.0563
# Epoch 283: decoder.4 sigma = 1.0294
# Epoch 283/300, Training Loss: 0.0045, Validation Loss: 0.0048
# Epoch 284: encoder.1 sigma = 1.0219
# Epoch 284: encoder.4 sigma = 1.0005
# Epoch 284: encoder.7 sigma = 0.8620
# Epoch 284: decoder.1 sigma = 1.0566
# Epoch 284: decoder.4 sigma = 1.0296
# Epoch 284/300, Training Loss: 0.0045, Validation Loss: 0.0049
# Epoch 285: encoder.1 sigma = 1.0220
# Epoch 285: encoder.4 sigma = 1.0006
# Epoch 285: encoder.7 sigma = 0.8617
# Epoch 285: decoder.1 sigma = 1.0569
# Epoch 285: decoder.4 sigma = 1.0297
# Epoch 285/300, Training Loss: 0.0044, Validation Loss: 0.0048
# Epoch 286: encoder.1 sigma = 1.0221
# Epoch 286: encoder.4 sigma = 1.0007
# Epoch 286: encoder.7 sigma = 0.8614
# Epoch 286: decoder.1 sigma = 1.0572
# Epoch 286: decoder.4 sigma = 1.0299
# Epoch 286/300, Training Loss: 0.0043, Validation Loss: 0.0048
# Epoch 287: encoder.1 sigma = 1.0221
# Epoch 287: encoder.4 sigma = 1.0007
# Epoch 287: encoder.7 sigma = 0.8611
# Epoch 287: decoder.1 sigma = 1.0574
# Epoch 287: decoder.4 sigma = 1.0301
# Epoch 287/300, Training Loss: 0.0043, Validation Loss: 0.0049
# Epoch 288: encoder.1 sigma = 1.0222
# Epoch 288: encoder.4 sigma = 1.0007
# Epoch 288: encoder.7 sigma = 0.8608
# Epoch 288: decoder.1 sigma = 1.0578
# Epoch 288: decoder.4 sigma = 1.0303
# Epoch 288/300, Training Loss: 0.0043, Validation Loss: 0.0048
# Epoch 289: encoder.1 sigma = 1.0223
# Epoch 289: encoder.4 sigma = 1.0007
# Epoch 289: encoder.7 sigma = 0.8605
# Epoch 289: decoder.1 sigma = 1.0580
# Epoch 289: decoder.4 sigma = 1.0305
# Epoch 289/300, Training Loss: 0.0043, Validation Loss: 0.0047
# Epoch 290: encoder.1 sigma = 1.0223
# Epoch 290: encoder.4 sigma = 1.0007
# Epoch 290: encoder.7 sigma = 0.8602
# Epoch 290: decoder.1 sigma = 1.0583
# Epoch 290: decoder.4 sigma = 1.0307
# Epoch 290/300, Training Loss: 0.0043, Validation Loss: 0.0048
# Epoch 291: encoder.1 sigma = 1.0225
# Epoch 291: encoder.4 sigma = 1.0008
# Epoch 291: encoder.7 sigma = 0.8598
# Epoch 291: decoder.1 sigma = 1.0586
# Epoch 291: decoder.4 sigma = 1.0309
# Epoch 291/300, Training Loss: 0.0043, Validation Loss: 0.0050
# Epoch 292: encoder.1 sigma = 1.0224
# Epoch 292: encoder.4 sigma = 1.0007
# Epoch 292: encoder.7 sigma = 0.8595
# Epoch 292: decoder.1 sigma = 1.0589
# Epoch 292: decoder.4 sigma = 1.0311
# Epoch 292/300, Training Loss: 0.0044, Validation Loss: 0.0049
# Epoch 293: encoder.1 sigma = 1.0226
# Epoch 293: encoder.4 sigma = 1.0008
# Epoch 293: encoder.7 sigma = 0.8592
# Epoch 293: decoder.1 sigma = 1.0592
# Epoch 293: decoder.4 sigma = 1.0313
# Epoch 293/300, Training Loss: 0.0043, Validation Loss: 0.0048
# Epoch 294: encoder.1 sigma = 1.0226
# Epoch 294: encoder.4 sigma = 1.0008
# Epoch 294: encoder.7 sigma = 0.8589
# Epoch 294: decoder.1 sigma = 1.0595
# Epoch 294: decoder.4 sigma = 1.0315
# Epoch 294/300, Training Loss: 0.0042, Validation Loss: 0.0047
# Epoch 295: encoder.1 sigma = 1.0227
# Epoch 295: encoder.4 sigma = 1.0008
# Epoch 295: encoder.7 sigma = 0.8585
# Epoch 295: decoder.1 sigma = 1.0598
# Epoch 295: decoder.4 sigma = 1.0317
# Epoch 295/300, Training Loss: 0.0044, Validation Loss: 0.0047
# Epoch 296: encoder.1 sigma = 1.0229
# Epoch 296: encoder.4 sigma = 1.0008
# Epoch 296: encoder.7 sigma = 0.8581
# Epoch 296: decoder.1 sigma = 1.0601
# Epoch 296: decoder.4 sigma = 1.0320
# Epoch 296/300, Training Loss: 0.0043, Validation Loss: 0.0050
# Epoch 297: encoder.1 sigma = 1.0228
# Epoch 297: encoder.4 sigma = 1.0008
# Epoch 297: encoder.7 sigma = 0.8578
# Epoch 297: decoder.1 sigma = 1.0604
# Epoch 297: decoder.4 sigma = 1.0321
# Epoch 297/300, Training Loss: 0.0043, Validation Loss: 0.0049
# Epoch 298: encoder.1 sigma = 1.0230
# Epoch 298: encoder.4 sigma = 1.0008
# Epoch 298: encoder.7 sigma = 0.8573
# Epoch 298: decoder.1 sigma = 1.0607
# Epoch 298: decoder.4 sigma = 1.0323
# Epoch 298/300, Training Loss: 0.0043, Validation Loss: 0.0047
# Epoch 299: encoder.1 sigma = 1.0230
# Epoch 299: encoder.4 sigma = 1.0008
# Epoch 299: encoder.7 sigma = 0.8570
# Epoch 299: decoder.1 sigma = 1.0610
# Epoch 299: decoder.4 sigma = 1.0326
# Epoch 299/300, Training Loss: 0.0043, Validation Loss: 0.0046
# Epoch 300: encoder.1 sigma = 1.0230
# Epoch 300: encoder.4 sigma = 1.0008
# Epoch 300: encoder.7 sigma = 0.8565
# Epoch 300: decoder.1 sigma = 1.0613
# Epoch 300: decoder.4 sigma = 1.0327
# Epoch 300/300, Training Loss: 0.0042, Validation Loss: 0.0048

# %%
# 绘制损失曲线
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Training loss')
plt.plot(valid_loss, label='Validation loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 可视化重建结果
def visualize_reconstructions(model, data_loader):
    model.eval()
    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)

            inputs = inputs.cpu().numpy()
            outputs = outputs.cpu().numpy()

            plt.figure(figsize=(20, 4))
            for i in range(5):
                plt.subplot(2, 5, i + 1)
                plt.imshow(np.transpose(inputs[i], (1, 2, 0)))
                plt.axis('off')

                plt.subplot(2, 5, i + 6)
                plt.imshow(np.transpose(outputs[i], (1, 2, 0)))
                plt.axis('off')
            break
    plt.show()

# 测试并可视化重建结果
visualize_reconstructions(autoencoder, valid_loader)
